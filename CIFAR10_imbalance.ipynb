# %%
import argparse
import os
import torch
import random 
import numpy as np 
import torch.optim
import torch.nn as nn
import torch.utils.data
import torch.nn.functional as F
from torch.autograd import Variable
import torch.backends.cudnn as cudnn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt 
from itertools import cycle
import pickle
import sys

from resnetv2 import PreActResNet18 as ResNet18  
from utils import Labeled_dataset


parser = argparse.ArgumentParser(description='PyTorch Cifar10_100 Training')
parser.add_argument('--lr', default=0.1, type=float, help='initial learning rate')
parser.add_argument('--data_dir', help='The directory for data', default='trans_data', type=str)
parser.add_argument('--momentum', default=0.9, type=float, help='momentum')
parser.add_argument('--weight_decay', default=5e-4, type=float, help='weight decay')
parser.add_argument('--epochs', default=100, type=int, help='number of total epochs to run')
parser.add_argument('--print_freq', default=50, type=int, help='print frequency')
parser.add_argument('--decreasing_lr', default='60,80', help='decreasing strategy')
parser.add_argument('--save_dir', help='The directory used to save the trained models', default='cifar10_cil', type=str)
parser.add_argument('--gpu', type=int, default=0, help='gpu device id')
parser.add_argument('--seed', type=int, default=None, help='random seed')
parser.add_argument('--batch_size', default=128, type=int, help='batch size')
parser.add_argument('--load_model', default=False, type=eval, choices=[True, False], help='load last checkpoint to continue training')

best_prec1 = 0

# %%
def validate(val_loader, model, criterion, if_main=False):

    losses = AverageMeter()
    top1 = AverageMeter()

    # switch to evaluate mode
    model.eval()

    for i, (input, target) in enumerate(val_loader):
        input = input.cuda()
        target = target.long().cuda()

        # compute output
        with torch.no_grad():
            output = model(input, main_fc=if_main)
            loss = criterion(output, target)

        output = output.float()
        loss = loss.float()

        # measure accuracy and record loss
        prec1 = accuracy(output.data, target)[0]
        losses.update(loss.item(), input.size(0))
        top1.update(prec1.item(), input.size(0))

        if i % args.print_freq == 0:
            print('Test: [{0}/{1}]\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Accuracy {top1.val:.3f} ({top1.avg:.3f})'.format(
                      i, len(val_loader), loss=losses, top1=top1))

    print('valid_accuracy {top1.avg:.3f}'.format(top1=top1))

    return top1.avg

# %%
def train(rand_loader, new_balance_loader, old_balance_loader, model, criterion, optimizer, epoch):
    
    losses = AverageMeter()
    top1 = AverageMeter()

    coef_old = int(args.batch_size*4/5)/64
    coef_new = int(args.batch_size/5)/64

    # switch to train mode
    model.train()

    new_balance = iter(new_balance_loader)
    old_balance = iter(old_balance_loader)

    for i, (input, target) in enumerate(rand_loader):

        try:
            bal_new_img, bal_new_target = next(new_balance)
        except StopIteration:
            new_balance = iter(new_balance_loader)
            bal_new_img, bal_new_target = next(new_balance)

        try:
            bal_old_img, bal_old_target = next(old_balance)
        except StopIteration:
            old_balance = iter(old_balance_loader)
            bal_old_img, bal_old_target = next(old_balance)

        bal_new_img = bal_new_img.cuda()
        bal_old_img = bal_old_img.cuda()
        input = input.cuda()

        bal_new_target = bal_new_target.long().cuda()
        bal_old_target = bal_old_target.long().cuda()
        target = target.long().cuda()

        # random input
        output_gt = model(input, main_fc=False)
        loss_rand = criterion(output_gt, target)
        
        
        # balance inputs
        output_bal_new = model(bal_new_img, main_fc=True)
        output_bal_old = model(bal_old_img, main_fc=True)
        loss_balance = criterion(output_bal_new, bal_new_target)*coef_new + criterion(output_bal_old, bal_old_target)*coef_old
        
        if tensor_allNaN(output_gt):
            print('output_gt')
            sys.exit()
        if tensor_allNaN(loss_rand):
            print('loss_rand')
            sys.exit()
        if tensor_allNaN(output_bal_new):
            print('output_bal_new')
            sys.exit()
        if tensor_allNaN(output_bal_old):
            print('output_bal_old')
            sys.exit()
        if tensor_allNaN(loss_balance):
            print('loss_balance')  
            sys.exit()
        
        
        loss = (loss_balance + loss_rand)*0.5

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        output = output_gt.float()
        loss = loss.float()
        # measure accuracy and record loss
        prec1 = accuracy(output.data, target)[0]   
        losses.update(loss.item(), input.size(0))
        top1.update(prec1.item(), input.size(0))

        if i % args.print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Accuracy {top1.val:.3f} ({top1.avg:.3f})'.format(
                      epoch, i, len(rand_loader), loss=losses, top1=top1))
            

    print('train_accuracy {top1.avg:.3f}'.format(top1=top1))

    return top1.avg

# %%
def save_checkpoint(state, filename='weight.pt'):
    """
    Save the training model
    """
    torch.save(state, filename)

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
# output.shape = [batch size, num_class]
# a = torch.tensor([[0.1, 0.9, 0.1], [0.8, 0.2, 0.1], [0.7, 0.3, 0.9]])
# b = torch.tensor([1, 1, 2])
# accuracy(a, b, topk=(, 2))
# [tensor(66.6667), tensor(100.)]


def accuracy(output, target, topk=(1,)):
    """Computes the precision@k for the specified values of k"""
    maxk = max(topk)
    batch_size = target.size(0)

    _, pred = output.topk(maxk, 1, True, True)
    pred = pred.t()
    correct = pred.eq(target.view(1, -1).expand_as(pred))

    res = []
    for k in topk:
        correct_k = correct[:k].view(-1).float().sum(0)
        
        res.append(correct_k.mul_(100.0 / batch_size))
    return res

# %%
##### TO-DO #######
# output.shape = [batch size, num_class]

def confusion_classWise(output, target):
    '''class wise confusion matrix'''
    
    maxk = max(topk)
    batch_size = target.size(0)

    _, pred = output.topk(maxk, 1, True, True)
    pred = pred.t()
    correct = pred.eq(target.view(1, -1).expand_as(pred))

    res = []
    for k in topk:
        correct_k = correct[:k].view(-1).float().sum(0)
        
        res.append(correct_k.mul_(100.0 / batch_size))
    return res

# %%
def setup_seed(seed): 
    torch.manual_seed(seed) 
    torch.cuda.manual_seed_all(seed) 
    np.random.seed(seed) 
    random.seed(seed) 
    torch.backends.cudnn.deterministic = True

# %%
def tensor_allNaN(tensor):
    all_Nan = torch.isnan(tensor).all()
    if all_Nan:
        return True
    else:
        return False

# %% [markdown]
# # ==== below ================

# %% [markdown]
# ### prepare data

# %%
global args, best_prec1

# %%
# jupyter notebook input workaround
# args = parser.parse_args()
args = parser.parse_args(args=['--save_dir', 'output', 
                               '--data_dir', 'trans_data', 
                               '--gpu', '2', 
                               '--epochs', '200', 
                               '--load_model', 'False',
                               '--seed', '1'
                              ])

print(args)
# Out:
# Namespace(batch_size=128, data_dir='trans_data', decreasing_lr='60,80', epochs=200, gpu=2, load_model=False, lr=0.1, momentum=0.9, print_freq=50, save_dir='output', seed=1, weight_decay=0.0005)

# %%
path_head = args.data_dir
train_path = os.path.join(path_head,'4500_labeled_images_cifar10_train.pkl')
old_img_path = os.path.join(path_head,'100_labeled_images_cifar10_train.pkl')
val_path = os.path.join(path_head,'500_labeled_images_cifar10_val.pkl')
test_path = os.path.join(path_head,'labeled_images_cifar10_test.pkl')
sequence = np.random.permutation(10)
print('class sequence: ', sequence)

torch.cuda.set_device(int(args.gpu))

if args.seed:
    setup_seed(args.seed)

os.makedirs(args.save_dir, exist_ok=True)

train_trans = transforms.Compose([
        transforms.ToPILImage(),
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, 4),
        transforms.ToTensor()
    ])

val_trans = transforms.Compose([
        transforms.ToPILImage(),
        transforms.ToTensor()
    ])

criterion = nn.CrossEntropyLoss()
criterion = criterion.cuda()
decreasing_lr = list(map(int, args.decreasing_lr.split(',')))

model = ResNet18(num_classes=10)
model.cuda()

starting_epoch = 0

optimizer = torch.optim.SGD(model.parameters(), args.lr,
                            momentum=args.momentum,
                            weight_decay=args.weight_decay)

scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=decreasing_lr, gamma=0.1)


#prepare dataset
train_dataset = Labeled_dataset(train_path, train_trans, sequence[8:10], offset=8)
train_old_dataset = Labeled_dataset(old_img_path, train_trans, sequence[:8], offset=0)
val_dataset = Labeled_dataset(val_path, val_trans, sequence[:10], offset=0)

train_random_dataset = torch.utils.data.dataset.ConcatDataset((train_dataset,train_old_dataset))
# Out:
# class sequence:  [9 1 7 3 5 0 4 6 8 2]
# target list =  [8 2]
# target list =  [9 1 7 3 5 0 4 6]
# target list =  [9 1 7 3 5 0 4 6 8 2]

# %%
train_loader_random = torch.utils.data.DataLoader(
    train_random_dataset,
    batch_size=args.batch_size, shuffle=True,
    num_workers=2, pin_memory=True)

train_loader_balance_new = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=int(args.batch_size/5), shuffle=True,
    num_workers=2, pin_memory=True)

train_loader_balance_old = torch.utils.data.DataLoader(
    train_old_dataset,
    batch_size=int(args.batch_size*4/5), shuffle=True,
    num_workers=2, pin_memory=True)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=args.batch_size, shuffle=False,
    num_workers=2, pin_memory=True)

# %% [markdown]
# ### start to train

# %%
# if load a checkpoint or not
if args.load_model:
    checkpoint =  torch.load(os.path.join(args.save_dir, 'checkpoint.pt'))
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    scheduler.load_state_dict(checkpoint['scheduler'])
    starting_epoch = checkpoint['epoch']
    best_prec1 = checkpoint['best_prec1']
    print('starting_epoch: ', starting_epoch)
    print('best_prec1: ', best_prec1)



# index, acc
train_acc = [[],[]]
ta_bal = [[],[]]
ta_imba = [[],[]]


for epoch in range(starting_epoch, starting_epoch + args.epochs):
    print('='*50)
    print("The learning rate is {}".format(optimizer.param_groups[0]['lr']))

    train_accuracy = train(train_loader_random, train_loader_balance_new, train_loader_balance_old, model, criterion, optimizer, epoch)
    
    prec1_bal = validate(val_loader, model, criterion, if_main=True)
    prec1_imba = validate(val_loader, model, criterion, if_main=False)
    

    train_acc[0].append(epoch)
    ta_bal[0].append(epoch)
    ta_imba[0].append(epoch)
    
    train_acc[1].append(train_accuracy)
    ta_bal[1].append(prec1_bal)
    ta_imba[1].append(prec1_imba)

    scheduler.step()

    # remember best prec@1 and save checkpoint
    is_best = prec1_bal > best_prec1
    best_prec1 = max(prec1_bal, best_prec1)

    if is_best:
        save_checkpoint({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
        }, filename=os.path.join(args.save_dir, 'best_model.pt'))

    save_checkpoint({
        'epoch': epoch + 1,
        'state_dict': model.state_dict(),
        'best_prec1': best_prec1,
        'optimizer': optimizer.state_dict(),
        'scheduler': scheduler.state_dict(),
    }, filename=os.path.join(args.save_dir, 'checkpoint.pt'))

    plt.plot(train_acc[0], train_acc[1], label='train_acc')
    plt.plot(ta_bal[0], ta_bal[1], label='TA_bal')
    plt.plot(ta_imba[0], ta_imba[1], label='TA_imba')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(args.save_dir, 'net_train.png'))
    plt.close()
# Out:
# ==================================================
# The learning rate is 0.1
# Epoch: [0][0/77]	Loss 3.3693 (3.3693)	Accuracy 20.312 (20.312)
# Epoch: [0][50/77]	Loss 4.8590 (19.7423)	Accuracy 39.062 (44.531)
# train_accuracy 45.449
# Test: [0/40]	Loss 9.1246 (9.1246)	Accuracy 0.000 (0.000)
# valid_accuracy 8.920
# Test: [0/40]	Loss 6.2905 (6.2905)	Accuracy 0.000 (0.000)
# valid_accuracy 10.140
# ==================================================
# The learning rate is 0.1
# Epoch: [1][0/77]	Loss 8.5237 (8.5237)	Accuracy 35.156 (35.156)
# Epoch: [1][50/77]	Loss 2.9866 (7.6616)	Accuracy 46.094 (48.284)
# train_accuracy 47.786
# Test: [0/40]	Loss 2.2665 (2.2665)	Accuracy 0.000 (0.000)
# valid_accuracy 10.220
# Test: [0/40]	Loss 4.4859 (4.4859)	Accuracy 0.000 (0.000)
# valid_accuracy 10.000
# ==================================================
# The learning rate is 0.1
# Epoch: [2][0/77]	Loss 2.9102 (2.9102)	Accuracy 44.531 (44.531)
# Epoch: [2][50/77]	Loss 2.8086 (2.8577)	Accuracy 40.625 (45.389)
# train_accuracy 45.235
# Test: [0/40]	Loss 2.2977 (2.2977)	Accuracy 0.000 (0.000)
# valid_accuracy 10.340
# Test: [0/40]	Loss 4.4767 (4.4767)	Accuracy 0.000 (0.000)
# valid_accuracy 10.400
# ==================================================
# The learning rate is 0.1
# Epoch: [3][0/77]	Loss 2.8719 (2.8719)	Accuracy 46.875 (46.875)
# Epoch: [3][50/77]	Loss 3.0583 (2.9502)	Accuracy 52.344 (46.308)
# train_accuracy 46.306
# Test: [0/40]	Loss 2.2932 (2.2932)	Accuracy 0.000 (0.000)
# valid_accuracy 10.940
# Test: [0/40]	Loss 4.4816 (4.4816)	Accuracy 0.000 (0.000)
# valid_accuracy 10.980
# ==================================================
# The learning rate is 0.1
# Epoch: [4][0/77]	Loss 2.8113 (2.8113)	Accuracy 41.406 (41.406)
# Epoch: [4][50/77]	Loss 2.5873 (2.7793)	Accuracy 53.906 (48.223)
# train_accuracy 48.194
# Test: [0/40]	Loss 2.3144 (2.3144)	Accuracy 0.781 (0.781)
# valid_accuracy 10.460
# Test: [0/40]	Loss 4.5467 (4.5467)	Accuracy 0.000 (0.000)
# valid_accuracy 11.540
# ==================================================
# The learning rate is 0.1
# Epoch: [5][0/77]	Loss 2.8042 (2.8042)	Accuracy 50.000 (50.000)
# Epoch: [5][50/77]	Loss 2.8144 (2.9139)	Accuracy 50.781 (47.626)
# train_accuracy 47.429
# Test: [0/40]	Loss 2.2974 (2.2974)	Accuracy 0.000 (0.000)
# valid_accuracy 11.020
# Test: [0/40]	Loss 4.4669 (4.4669)	Accuracy 0.000 (0.000)
# valid_accuracy 10.620
# ==================================================
# The learning rate is 0.1
# Epoch: [6][0/77]	Loss 2.8341 (2.8341)	Accuracy 40.625 (40.625)
# Epoch: [6][50/77]	Loss 2.8512 (2.8134)	Accuracy 50.781 (47.840)
# train_accuracy 46.847
# Test: [0/40]	Loss 2.2631 (2.2631)	Accuracy 3.906 (3.906)
# valid_accuracy 11.080
# Test: [0/40]	Loss 4.4921 (4.4921)	Accuracy 0.000 (0.000)
# valid_accuracy 11.000
# ==================================================
# The learning rate is 0.1
# Epoch: [7][0/77]	Loss 2.7447 (2.7447)	Accuracy 51.562 (51.562)
# Epoch: [7][50/77]	Loss 2.8633 (2.8011)	Accuracy 43.750 (46.952)
# train_accuracy 46.510
# Test: [0/40]	Loss 2.3185 (2.3185)	Accuracy 0.000 (0.000)
# valid_accuracy 10.880
# Test: [0/40]	Loss 4.4707 (4.4707)	Accuracy 0.000 (0.000)
# valid_accuracy 10.720
# ==================================================
# The learning rate is 0.1
# Epoch: [8][0/77]	Loss 2.8780 (2.8780)	Accuracy 50.781 (50.781)
# Epoch: [8][50/77]	Loss 2.7388 (2.7933)	Accuracy 48.438 (48.009)
# train_accuracy 48.316
# Test: [0/40]	Loss 2.2847 (2.2847)	Accuracy 0.781 (0.781)
# valid_accuracy 11.040
# Test: [0/40]	Loss 4.5060 (4.5060)	Accuracy 0.000 (0.000)
# valid_accuracy 10.860
# ==================================================
# The learning rate is 0.1
# Epoch: [9][0/77]	Loss 2.9312 (2.9312)	Accuracy 43.750 (43.750)
# Epoch: [9][50/77]	Loss 2.7710 (2.7932)	Accuracy 52.344 (47.564)
# train_accuracy 47.939
# Test: [0/40]	Loss 2.3450 (2.3450)	Accuracy 0.000 (0.000)
# valid_accuracy 11.100
# Test: [0/40]	Loss 4.5158 (4.5158)	Accuracy 0.000 (0.000)
# valid_accuracy 10.820
# ==================================================
# The learning rate is 0.1
# Epoch: [10][0/77]	Loss 2.8135 (2.8135)	Accuracy 51.562 (51.562)
# Epoch: [10][50/77]	Loss 2.8122 (2.7972)	Accuracy 46.094 (48.238)
# train_accuracy 47.918
# Test: [0/40]	Loss 2.3169 (2.3169)	Accuracy 0.000 (0.000)
# valid_accuracy 11.360
# Test: [0/40]	Loss 4.4766 (4.4766)	Accuracy 0.000 (0.000)
# valid_accuracy 11.020
# ==================================================
# The learning rate is 0.1
# Epoch: [11][0/77]	Loss 2.6730 (2.6730)	Accuracy 50.781 (50.781)
# Epoch: [11][50/77]	Loss 2.7803 (2.7942)	Accuracy 53.125 (47.809)
# train_accuracy 47.827
# Test: [0/40]	Loss 2.2310 (2.2310)	Accuracy 0.781 (0.781)
# valid_accuracy 9.880
# Test: [0/40]	Loss 4.4952 (4.4952)	Accuracy 0.000 (0.000)
# valid_accuracy 11.820
# ==================================================
# The learning rate is 0.1
# Epoch: [12][0/77]	Loss 2.7965 (2.7965)	Accuracy 51.562 (51.562)
# Epoch: [12][50/77]	Loss 2.7945 (2.7548)	Accuracy 46.875 (48.361)
# train_accuracy 48.694
# Test: [0/40]	Loss 2.3312 (2.3312)	Accuracy 0.781 (0.781)
# valid_accuracy 11.580
# Test: [0/40]	Loss 4.5054 (4.5054)	Accuracy 0.000 (0.000)
# valid_accuracy 11.560
# ==================================================
# The learning rate is 0.1
# Epoch: [13][0/77]	Loss 2.7356 (2.7356)	Accuracy 53.906 (53.906)
# Epoch: [13][50/77]	Loss 2.7808 (2.7439)	Accuracy 56.250 (49.663)
# train_accuracy 49.694
# Test: [0/40]	Loss 2.0764 (2.0764)	Accuracy 3.125 (3.125)
# valid_accuracy 9.860
# Test: [0/40]	Loss 4.6637 (4.6637)	Accuracy 0.000 (0.000)
# valid_accuracy 10.040
# ==================================================
# The learning rate is 0.1
# Epoch: [14][0/77]	Loss 2.8363 (2.8363)	Accuracy 46.094 (46.094)
# Epoch: [14][50/77]	Loss 2.8992 (2.7912)	Accuracy 53.125 (51.700)
# train_accuracy 52.378
# Test: [0/40]	Loss 2.3173 (2.3173)	Accuracy 0.000 (0.000)
# valid_accuracy 12.400
# Test: [0/40]	Loss 4.4883 (4.4883)	Accuracy 0.000 (0.000)
# valid_accuracy 12.480
# ==================================================
# The learning rate is 0.1
# Epoch: [15][0/77]	Loss 2.7673 (2.7673)	Accuracy 57.812 (57.812)
# Epoch: [15][50/77]	Loss 2.7169 (2.7686)	Accuracy 57.031 (54.197)
# train_accuracy 54.245
# Test: [0/40]	Loss 2.2978 (2.2978)	Accuracy 0.000 (0.000)
# valid_accuracy 12.960
# Test: [0/40]	Loss 4.5269 (4.5269)	Accuracy 0.000 (0.000)
# valid_accuracy 13.080
# ==================================================
# The learning rate is 0.1
# Epoch: [16][0/77]	Loss 2.7214 (2.7214)	Accuracy 50.781 (50.781)
# Epoch: [16][50/77]	Loss 2.7432 (2.7131)	Accuracy 55.469 (54.688)
# train_accuracy 52.153
# Test: [0/40]	Loss 2.4123 (2.4123)	Accuracy 0.781 (0.781)
# valid_accuracy 11.180
# Test: [0/40]	Loss 4.7238 (4.7238)	Accuracy 0.000 (0.000)
# valid_accuracy 10.000
# ==================================================
# The learning rate is 0.1
# Epoch: [17][0/77]	Loss 5.0718 (5.0718)	Accuracy 44.531 (44.531)
# Epoch: [17][50/77]	Loss 3.1040 (3.8262)	Accuracy 50.000 (47.381)
# train_accuracy 47.306
# Test: [0/40]	Loss 2.3105 (2.3105)	Accuracy 0.000 (0.000)
# valid_accuracy 10.360
# Test: [0/40]	Loss 4.5585 (4.5585)	Accuracy 0.000 (0.000)
# valid_accuracy 10.000
# ==================================================
# The learning rate is 0.1
# Epoch: [18][0/77]	Loss 2.9151 (2.9151)	Accuracy 42.969 (42.969)
# Epoch: [18][50/77]	Loss 2.8023 (2.8369)	Accuracy 49.219 (45.956)
# train_accuracy 45.684
# Test: [0/40]	Loss 2.3122 (2.3122)	Accuracy 0.000 (0.000)
# valid_accuracy 10.660
# Test: [0/40]	Loss 4.4789 (4.4789)	Accuracy 0.000 (0.000)
# valid_accuracy 10.560
# ==================================================
# The learning rate is 0.1
# Epoch: [19][0/77]	Loss 2.7844 (2.7844)	Accuracy 45.312 (45.312)
# Epoch: [19][50/77]	Loss 2.8460 (2.8188)	Accuracy 57.031 (47.350)
# train_accuracy 47.378
# Test: [0/40]	Loss 2.2786 (2.2786)	Accuracy 1.562 (1.562)
# valid_accuracy 10.660
# Test: [0/40]	Loss 4.4978 (4.4978)	Accuracy 0.000 (0.000)
# valid_accuracy 10.020
# ==================================================
# The learning rate is 0.1
# Epoch: [20][0/77]	Loss 2.8904 (2.8904)	Accuracy 39.062 (39.062)
# Epoch: [20][50/77]	Loss 2.8073 (2.8070)	Accuracy 41.406 (47.151)
# train_accuracy 47.439
# Test: [0/40]	Loss 2.2756 (2.2756)	Accuracy 3.125 (3.125)
# valid_accuracy 11.280
# Test: [0/40]	Loss 4.5184 (4.5184)	Accuracy 0.000 (0.000)
# valid_accuracy 10.020
# ==================================================
# The learning rate is 0.1
# Epoch: [21][0/77]	Loss 2.6892 (2.6892)	Accuracy 47.656 (47.656)
# Epoch: [21][50/77]	Loss 2.7755 (2.8005)	Accuracy 50.000 (47.227)
# train_accuracy 47.041
# Test: [0/40]	Loss 2.3100 (2.3100)	Accuracy 0.000 (0.000)
# valid_accuracy 11.100
# Test: [0/40]	Loss 4.4970 (4.4970)	Accuracy 0.000 (0.000)
# valid_accuracy 10.760
# ==================================================
# The learning rate is 0.1
# Epoch: [22][0/77]	Loss 2.8671 (2.8671)	Accuracy 40.625 (40.625)
# Epoch: [22][50/77]	Loss 2.8011 (2.7966)	Accuracy 42.969 (46.078)
# train_accuracy 47.051
# Test: [0/40]	Loss 2.3159 (2.3159)	Accuracy 0.000 (0.000)
# valid_accuracy 11.200
# Test: [0/40]	Loss 4.4986 (4.4986)	Accuracy 0.000 (0.000)
# valid_accuracy 10.760
# ==================================================
# The learning rate is 0.1
# Epoch: [23][0/77]	Loss 2.7904 (2.7904)	Accuracy 50.000 (50.000)
# Epoch: [23][50/77]	Loss 2.8379 (2.7828)	Accuracy 57.812 (48.499)
# train_accuracy 49.500
# Test: [0/40]	Loss 2.2858 (2.2858)	Accuracy 0.781 (0.781)
# valid_accuracy 12.260
# Test: [0/40]	Loss 4.5086 (4.5086)	Accuracy 0.000 (0.000)
# valid_accuracy 11.420
# ==================================================
# The learning rate is 0.1
# Epoch: [24][0/77]	Loss 2.7960 (2.7960)	Accuracy 52.344 (52.344)
# Epoch: [24][50/77]	Loss 2.7127 (2.7405)	Accuracy 61.719 (56.357)
# train_accuracy 57.459
# Test: [0/40]	Loss 2.1927 (2.1927)	Accuracy 3.125 (3.125)
# valid_accuracy 15.060
# Test: [0/40]	Loss 4.5734 (4.5734)	Accuracy 0.000 (0.000)
# valid_accuracy 14.360
# ==================================================
# The learning rate is 0.1
# Epoch: [25][0/77]	Loss 2.6731 (2.6731)	Accuracy 66.406 (66.406)
# Epoch: [25][50/77]	Loss 2.4074 (2.5657)	Accuracy 65.625 (66.805)
# train_accuracy 67.643
# Test: [0/40]	Loss 2.0052 (2.0052)	Accuracy 21.094 (21.094)
# valid_accuracy 20.860
# Test: [0/40]	Loss 4.8649 (4.8649)	Accuracy 0.000 (0.000)
# valid_accuracy 16.100
# ==================================================
# The learning rate is 0.1
# Epoch: [26][0/77]	Loss 2.4911 (2.4911)	Accuracy 71.875 (71.875)
# Epoch: [26][50/77]	Loss 2.1057 (2.4650)	Accuracy 72.656 (70.113)
# train_accuracy 70.439
# Test: [0/40]	Loss 1.9850 (1.9850)	Accuracy 36.719 (36.719)
# valid_accuracy 20.920
# Test: [0/40]	Loss 4.6687 (4.6687)	Accuracy 0.000 (0.000)
# valid_accuracy 16.220
# ==================================================
# The learning rate is 0.1
# Epoch: [27][0/77]	Loss 2.3912 (2.3912)	Accuracy 71.875 (71.875)
# Epoch: [27][50/77]	Loss 2.1908 (2.4333)	Accuracy 72.656 (72.656)
# train_accuracy 73.184
# Test: [0/40]	Loss 2.2985 (2.2985)	Accuracy 17.969 (17.969)
# valid_accuracy 17.340
# Test: [0/40]	Loss 4.1309 (4.1309)	Accuracy 0.000 (0.000)
# valid_accuracy 16.380
# ==================================================
# The learning rate is 0.1
# Epoch: [28][0/77]	Loss 2.4536 (2.4536)	Accuracy 73.438 (73.438)
# Epoch: [28][50/77]	Loss 2.2560 (2.3866)	Accuracy 79.688 (73.361)
# train_accuracy 72.806
# Test: [0/40]	Loss 2.1381 (2.1381)	Accuracy 17.969 (17.969)
# valid_accuracy 15.820
# Test: [0/40]	Loss 4.6347 (4.6347)	Accuracy 0.000 (0.000)
# valid_accuracy 15.400
# ==================================================
# The learning rate is 0.1
# Epoch: [29][0/77]	Loss 2.8084 (2.8084)	Accuracy 76.562 (76.562)
# Epoch: [29][50/77]	Loss 2.5488 (2.6109)	Accuracy 74.219 (72.059)
# train_accuracy 72.571
# Test: [0/40]	Loss 1.9281 (1.9281)	Accuracy 30.469 (30.469)
# valid_accuracy 22.760
# Test: [0/40]	Loss 4.3672 (4.3672)	Accuracy 0.000 (0.000)
# valid_accuracy 16.480
# ==================================================
# The learning rate is 0.1
# Epoch: [30][0/77]	Loss 2.3439 (2.3439)	Accuracy 74.219 (74.219)
# Epoch: [30][50/77]	Loss 2.3293 (2.3824)	Accuracy 70.312 (75.322)
# train_accuracy 75.837
# Test: [0/40]	Loss 1.7899 (1.7899)	Accuracy 33.594 (33.594)
# valid_accuracy 25.720
# Test: [0/40]	Loss 4.6739 (4.6739)	Accuracy 0.000 (0.000)
# valid_accuracy 16.960
# ==================================================
# The learning rate is 0.1
# Epoch: [31][0/77]	Loss 2.2495 (2.2495)	Accuracy 84.375 (84.375)
# Epoch: [31][50/77]	Loss 2.0971 (2.2515)	Accuracy 84.375 (77.834)
# train_accuracy 78.061
# Test: [0/40]	Loss 1.7980 (1.7980)	Accuracy 20.312 (20.312)
# valid_accuracy 27.340
# Test: [0/40]	Loss 4.8053 (4.8053)	Accuracy 0.000 (0.000)
# valid_accuracy 16.800
# ==================================================
# The learning rate is 0.1
# Epoch: [32][0/77]	Loss 2.0894 (2.0894)	Accuracy 79.688 (79.688)
# Epoch: [32][50/77]	Loss 2.4550 (2.3236)	Accuracy 76.562 (77.267)
# train_accuracy 77.163
# Test: [0/40]	Loss 1.9239 (1.9239)	Accuracy 13.281 (13.281)
# valid_accuracy 22.600
# Test: [0/40]	Loss 4.2522 (4.2522)	Accuracy 0.000 (0.000)
# valid_accuracy 17.720
# ==================================================
# The learning rate is 0.1
# Epoch: [33][0/77]	Loss 2.4380 (2.4380)	Accuracy 84.375 (84.375)
# Epoch: [33][50/77]	Loss 2.1603 (2.2525)	Accuracy 85.938 (78.830)
# train_accuracy 79.092
# Test: [0/40]	Loss 1.3795 (1.3795)	Accuracy 55.469 (55.469)
# valid_accuracy 24.420
# Test: [0/40]	Loss 4.4171 (4.4171)	Accuracy 0.000 (0.000)
# valid_accuracy 17.480
# ==================================================
# The learning rate is 0.1
# Epoch: [34][0/77]	Loss 2.1514 (2.1514)	Accuracy 79.688 (79.688)
# Epoch: [34][50/77]	Loss 2.0966 (2.1245)	Accuracy 84.375 (80.653)
# train_accuracy 81.000
# Test: [0/40]	Loss 2.0464 (2.0464)	Accuracy 24.219 (24.219)
# valid_accuracy 22.280
# Test: [0/40]	Loss 3.5845 (3.5845)	Accuracy 0.000 (0.000)
# valid_accuracy 17.840
# ==================================================
# The learning rate is 0.1
# Epoch: [35][0/77]	Loss 1.7661 (1.7661)	Accuracy 85.156 (85.156)
# Epoch: [35][50/77]	Loss 2.0261 (2.0921)	Accuracy 85.156 (80.898)
# train_accuracy 80.888
# Test: [0/40]	Loss 1.6451 (1.6451)	Accuracy 32.031 (32.031)
# valid_accuracy 26.840
# Test: [0/40]	Loss 4.1691 (4.1691)	Accuracy 0.000 (0.000)
# valid_accuracy 17.620
# ==================================================
# The learning rate is 0.1
# Epoch: [36][0/77]	Loss 1.9489 (1.9489)	Accuracy 79.688 (79.688)
# Epoch: [36][50/77]	Loss 1.8861 (2.0707)	Accuracy 86.719 (81.219)
# train_accuracy 81.204
# Test: [0/40]	Loss 1.3619 (1.3619)	Accuracy 53.125 (53.125)
# valid_accuracy 28.100
# Test: [0/40]	Loss 3.5117 (3.5117)	Accuracy 0.000 (0.000)
# valid_accuracy 17.960
# ==================================================
# The learning rate is 0.1
# Epoch: [37][0/77]	Loss 1.8184 (1.8184)	Accuracy 83.594 (83.594)
# Epoch: [37][50/77]	Loss 2.0127 (2.0051)	Accuracy 85.156 (81.189)
# train_accuracy 80.918
# Test: [0/40]	Loss 1.4225 (1.4225)	Accuracy 25.000 (25.000)
# valid_accuracy 29.520
# Test: [0/40]	Loss 4.4426 (4.4426)	Accuracy 0.000 (0.000)
# valid_accuracy 16.800
# ==================================================
# The learning rate is 0.1
# Epoch: [38][0/77]	Loss 1.9397 (1.9397)	Accuracy 84.375 (84.375)
# Epoch: [38][50/77]	Loss 2.9028 (1.9467)	Accuracy 76.562 (81.939)
# train_accuracy 81.031
# Test: [0/40]	Loss 1.9000 (1.9000)	Accuracy 27.344 (27.344)
# valid_accuracy 31.240
# Test: [0/40]	Loss 4.9677 (4.9677)	Accuracy 0.000 (0.000)
# valid_accuracy 17.720
# ==================================================
# The learning rate is 0.1
# Epoch: [39][0/77]	Loss 2.1220 (2.1220)	Accuracy 82.812 (82.812)
# Epoch: [39][50/77]	Loss 1.8352 (2.1602)	Accuracy 82.812 (78.768)
# train_accuracy 79.133
# Test: [0/40]	Loss 1.7407 (1.7407)	Accuracy 32.031 (32.031)
# valid_accuracy 28.400
# Test: [0/40]	Loss 3.8700 (3.8700)	Accuracy 0.000 (0.000)
# valid_accuracy 17.500
# ==================================================
# The learning rate is 0.1
# Epoch: [40][0/77]	Loss 2.2524 (2.2524)	Accuracy 82.812 (82.812)
# Epoch: [40][50/77]	Loss 1.9930 (1.9859)	Accuracy 78.125 (80.300)
# train_accuracy 80.663
# Test: [0/40]	Loss 1.7932 (1.7932)	Accuracy 35.938 (35.938)
# valid_accuracy 30.540
# Test: [0/40]	Loss 3.7650 (3.7650)	Accuracy 0.000 (0.000)
# valid_accuracy 17.940
# ==================================================
# The learning rate is 0.1
# Epoch: [41][0/77]	Loss 2.0333 (2.0333)	Accuracy 71.875 (71.875)
# Epoch: [41][50/77]	Loss 1.7781 (1.9559)	Accuracy 75.781 (80.407)
# train_accuracy 80.602
# Test: [0/40]	Loss 1.8667 (1.8667)	Accuracy 46.875 (46.875)
# valid_accuracy 26.500
# Test: [0/40]	Loss 3.9404 (3.9404)	Accuracy 0.000 (0.000)
# valid_accuracy 17.340
# ==================================================
# The learning rate is 0.1
# Epoch: [42][0/77]	Loss 1.8285 (1.8285)	Accuracy 75.781 (75.781)
# Epoch: [42][50/77]	Loss 1.9824 (2.2153)	Accuracy 79.688 (79.764)
# train_accuracy 80.969
# Test: [0/40]	Loss 1.5311 (1.5311)	Accuracy 46.875 (46.875)
# valid_accuracy 31.520
# Test: [0/40]	Loss 3.6131 (3.6131)	Accuracy 0.000 (0.000)
# valid_accuracy 18.380
# ==================================================
# The learning rate is 0.1
# Epoch: [43][0/77]	Loss 1.9965 (1.9965)	Accuracy 79.688 (79.688)
# Epoch: [43][50/77]	Loss 1.7332 (1.8038)	Accuracy 81.250 (82.077)
# train_accuracy 82.031
# Test: [0/40]	Loss 1.1656 (1.1656)	Accuracy 57.812 (57.812)
# valid_accuracy 31.400
# Test: [0/40]	Loss 3.5723 (3.5723)	Accuracy 0.000 (0.000)
# valid_accuracy 17.760
# ==================================================
# The learning rate is 0.1
# Epoch: [44][0/77]	Loss 2.4629 (2.4629)	Accuracy 79.688 (79.688)
# Epoch: [44][50/77]	Loss 1.8356 (1.9748)	Accuracy 83.594 (80.178)
# train_accuracy 80.714
# Test: [0/40]	Loss 1.7655 (1.7655)	Accuracy 44.531 (44.531)
# valid_accuracy 29.180
# Test: [0/40]	Loss 2.9849 (2.9849)	Accuracy 1.562 (1.562)
# valid_accuracy 18.660
# ==================================================
# The learning rate is 0.1
# Epoch: [45][0/77]	Loss 1.8298 (1.8298)	Accuracy 77.344 (77.344)
# Epoch: [45][50/77]	Loss 1.3849 (1.6394)	Accuracy 82.031 (82.062)
# train_accuracy 81.969
# Test: [0/40]	Loss 3.2651 (3.2651)	Accuracy 21.094 (21.094)
# valid_accuracy 27.700
# Test: [0/40]	Loss 4.9960 (4.9960)	Accuracy 1.562 (1.562)
# valid_accuracy 17.780
# ==================================================
# The learning rate is 0.1
# Epoch: [46][0/77]	Loss 1.9764 (1.9764)	Accuracy 75.781 (75.781)
# Epoch: [46][50/77]	Loss 1.3592 (1.7631)	Accuracy 86.719 (82.261)
# train_accuracy 82.061
# Test: [0/40]	Loss 1.8120 (1.8120)	Accuracy 32.812 (32.812)
# valid_accuracy 33.480
# Test: [0/40]	Loss 3.5862 (3.5862)	Accuracy 3.906 (3.906)
# valid_accuracy 20.880
# ==================================================
# The learning rate is 0.1
# Epoch: [47][0/77]	Loss 1.3899 (1.3899)	Accuracy 84.375 (84.375)
# Epoch: [47][50/77]	Loss 1.5656 (1.5673)	Accuracy 87.500 (82.215)
# train_accuracy 82.163
# Test: [0/40]	Loss 1.4586 (1.4586)	Accuracy 53.125 (53.125)
# valid_accuracy 35.000
# Test: [0/40]	Loss 3.2798 (3.2798)	Accuracy 2.344 (2.344)
# valid_accuracy 18.840
# ==================================================
# The learning rate is 0.1
# Epoch: [48][0/77]	Loss 1.4441 (1.4441)	Accuracy 82.812 (82.812)
# Epoch: [48][50/77]	Loss 1.3155 (1.4863)	Accuracy 83.594 (82.629)
# train_accuracy 82.449
# Test: [0/40]	Loss 3.2116 (3.2116)	Accuracy 12.500 (12.500)
# valid_accuracy 23.500
# Test: [0/40]	Loss 5.1465 (5.1465)	Accuracy 0.000 (0.000)
# valid_accuracy 16.660
# ==================================================
# The learning rate is 0.1
# Epoch: [49][0/77]	Loss 2.4251 (2.4251)	Accuracy 82.031 (82.031)
# Epoch: [49][50/77]	Loss 1.8394 (2.2727)	Accuracy 86.719 (80.790)
# train_accuracy 81.439
# Test: [0/40]	Loss 1.5892 (1.5892)	Accuracy 52.344 (52.344)
# valid_accuracy 34.460
# Test: [0/40]	Loss 3.2199 (3.2199)	Accuracy 2.344 (2.344)
# valid_accuracy 21.120
# ==================================================
# The learning rate is 0.1
# Epoch: [50][0/77]	Loss 1.5222 (1.5222)	Accuracy 87.500 (87.500)
# Epoch: [50][50/77]	Loss 1.4119 (1.5690)	Accuracy 82.031 (84.023)
# train_accuracy 84.092
# Test: [0/40]	Loss 1.6520 (1.6520)	Accuracy 50.000 (50.000)
# valid_accuracy 37.040
# Test: [0/40]	Loss 3.4431 (3.4431)	Accuracy 7.812 (7.812)
# valid_accuracy 20.280
# ==================================================
# The learning rate is 0.1
# Epoch: [51][0/77]	Loss 1.2287 (1.2287)	Accuracy 89.062 (89.062)
# Epoch: [51][50/77]	Loss 2.4828 (1.4864)	Accuracy 83.594 (83.931)
# train_accuracy 82.908
# Test: [0/40]	Loss 1.4959 (1.4959)	Accuracy 50.000 (50.000)
# valid_accuracy 36.820
# Test: [0/40]	Loss 3.7826 (3.7826)	Accuracy 0.000 (0.000)
# valid_accuracy 18.440
# ==================================================
# The learning rate is 0.1
# Epoch: [52][0/77]	Loss 1.5070 (1.5070)	Accuracy 87.500 (87.500)
# Epoch: [52][50/77]	Loss 1.5889 (1.5392)	Accuracy 89.844 (83.869)
# train_accuracy 83.898
# Test: [0/40]	Loss 1.5080 (1.5080)	Accuracy 50.781 (50.781)
# valid_accuracy 41.280
# Test: [0/40]	Loss 3.2510 (3.2510)	Accuracy 5.469 (5.469)
# valid_accuracy 22.660
# ==================================================
# The learning rate is 0.1
# Epoch: [53][0/77]	Loss 1.2029 (1.2029)	Accuracy 85.156 (85.156)
# Epoch: [53][50/77]	Loss 1.3849 (1.3373)	Accuracy 84.375 (84.329)
# train_accuracy 84.857
# Test: [0/40]	Loss 2.0598 (2.0598)	Accuracy 33.594 (33.594)
# valid_accuracy 29.000
# Test: [0/40]	Loss 2.9858 (2.9858)	Accuracy 10.938 (10.938)
# valid_accuracy 21.140
# ==================================================
# The learning rate is 0.1
# Epoch: [54][0/77]	Loss 1.1245 (1.1245)	Accuracy 81.250 (81.250)
# Epoch: [54][50/77]	Loss 1.1786 (1.3330)	Accuracy 84.375 (84.360)
# train_accuracy 84.622
# Test: [0/40]	Loss 2.2420 (2.2420)	Accuracy 8.594 (8.594)
# valid_accuracy 30.280
# Test: [0/40]	Loss 3.4920 (3.4920)	Accuracy 0.781 (0.781)
# valid_accuracy 20.240
# ==================================================
# The learning rate is 0.1
# Epoch: [55][0/77]	Loss 1.1529 (1.1529)	Accuracy 89.062 (89.062)
# Epoch: [55][50/77]	Loss 0.9338 (1.0574)	Accuracy 83.594 (84.666)
# train_accuracy 84.582
# Test: [0/40]	Loss 2.2819 (2.2819)	Accuracy 28.906 (28.906)
# valid_accuracy 37.340
# Test: [0/40]	Loss 4.2869 (4.2869)	Accuracy 4.688 (4.688)
# valid_accuracy 22.380
# ==================================================
# The learning rate is 0.1
# Epoch: [56][0/77]	Loss 0.9529 (0.9529)	Accuracy 85.938 (85.938)
# Epoch: [56][50/77]	Loss 0.9366 (1.1277)	Accuracy 82.812 (84.789)
# train_accuracy 85.224
# Test: [0/40]	Loss 1.6350 (1.6350)	Accuracy 60.938 (60.938)
# valid_accuracy 41.520
# Test: [0/40]	Loss 2.4930 (2.4930)	Accuracy 25.000 (25.000)
# valid_accuracy 28.680
# ==================================================
# The learning rate is 0.1
# Epoch: [57][0/77]	Loss 0.8258 (0.8258)	Accuracy 84.375 (84.375)
# Epoch: [57][50/77]	Loss 0.8861 (0.8349)	Accuracy 85.938 (85.355)
# train_accuracy 85.510
# Test: [0/40]	Loss 2.6591 (2.6591)	Accuracy 29.688 (29.688)
# valid_accuracy 33.440
# Test: [0/40]	Loss 2.3394 (2.3394)	Accuracy 28.906 (28.906)
# valid_accuracy 29.020
# ==================================================
# The learning rate is 0.1
# Epoch: [58][0/77]	Loss 0.7034 (0.7034)	Accuracy 87.500 (87.500)
# Epoch: [58][50/77]	Loss 1.6190 (1.3871)	Accuracy 85.156 (84.252)
# train_accuracy 84.337
# Test: [0/40]	Loss 1.8861 (1.8861)	Accuracy 44.531 (44.531)
# valid_accuracy 41.300
# Test: [0/40]	Loss 3.1855 (3.1855)	Accuracy 3.906 (3.906)
# valid_accuracy 22.440
# ==================================================
# The learning rate is 0.1
# Epoch: [59][0/77]	Loss 1.3408 (1.3408)	Accuracy 82.031 (82.031)
# Epoch: [59][50/77]	Loss 1.0091 (1.1520)	Accuracy 85.156 (85.662)
# train_accuracy 86.173
# Test: [0/40]	Loss 1.5092 (1.5092)	Accuracy 63.281 (63.281)
# valid_accuracy 41.880
# Test: [0/40]	Loss 2.1566 (2.1566)	Accuracy 36.719 (36.719)
# valid_accuracy 26.000
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [60][0/77]	Loss 0.9724 (0.9724)	Accuracy 87.500 (87.500)
# Epoch: [60][50/77]	Loss 1.0262 (0.7039)	Accuracy 89.062 (87.148)
# train_accuracy 87.286
# Test: [0/40]	Loss 1.6938 (1.6938)	Accuracy 56.250 (56.250)
# valid_accuracy 44.600
# Test: [0/40]	Loss 2.3390 (2.3390)	Accuracy 39.062 (39.062)
# valid_accuracy 30.460
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [61][0/77]	Loss 0.5424 (0.5424)	Accuracy 92.188 (92.188)
# Epoch: [61][50/77]	Loss 0.6625 (0.5712)	Accuracy 85.938 (87.898)
# train_accuracy 87.755
# Test: [0/40]	Loss 1.9568 (1.9568)	Accuracy 53.125 (53.125)
# valid_accuracy 45.820
# Test: [0/40]	Loss 2.6930 (2.6930)	Accuracy 31.250 (31.250)
# valid_accuracy 30.600
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [62][0/77]	Loss 0.5285 (0.5285)	Accuracy 90.625 (90.625)
# Epoch: [62][50/77]	Loss 0.4022 (0.5094)	Accuracy 89.844 (88.297)
# train_accuracy 88.316
# Test: [0/40]	Loss 2.0548 (2.0548)	Accuracy 52.344 (52.344)
# valid_accuracy 44.080
# Test: [0/40]	Loss 2.4298 (2.4298)	Accuracy 39.844 (39.844)
# valid_accuracy 33.060
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [63][0/77]	Loss 0.5224 (0.5224)	Accuracy 82.031 (82.031)
# Epoch: [63][50/77]	Loss 0.3809 (0.4303)	Accuracy 89.062 (88.297)
# train_accuracy 88.337
# Test: [0/40]	Loss 2.7618 (2.7618)	Accuracy 38.281 (38.281)
# valid_accuracy 42.640
# Test: [0/40]	Loss 2.8303 (2.8303)	Accuracy 29.688 (29.688)
# valid_accuracy 33.260
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [64][0/77]	Loss 0.3705 (0.3705)	Accuracy 85.156 (85.156)
# Epoch: [64][50/77]	Loss 0.3772 (0.3831)	Accuracy 89.062 (88.725)
# train_accuracy 88.367
# Test: [0/40]	Loss 2.3183 (2.3183)	Accuracy 50.000 (50.000)
# valid_accuracy 44.500
# Test: [0/40]	Loss 2.6639 (2.6639)	Accuracy 39.844 (39.844)
# valid_accuracy 34.180
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [65][0/77]	Loss 0.3312 (0.3312)	Accuracy 85.156 (85.156)
# Epoch: [65][50/77]	Loss 0.3582 (0.3472)	Accuracy 86.719 (88.450)
# train_accuracy 88.449
# Test: [0/40]	Loss 2.3832 (2.3832)	Accuracy 48.438 (48.438)
# valid_accuracy 40.980
# Test: [0/40]	Loss 2.4506 (2.4506)	Accuracy 45.312 (45.312)
# valid_accuracy 34.480
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [66][0/77]	Loss 0.3018 (0.3018)	Accuracy 89.062 (89.062)
# Epoch: [66][50/77]	Loss 0.2449 (0.3156)	Accuracy 90.625 (89.185)
# train_accuracy 88.959
# Test: [0/40]	Loss 2.2626 (2.2626)	Accuracy 53.906 (53.906)
# valid_accuracy 44.400
# Test: [0/40]	Loss 2.7582 (2.7582)	Accuracy 40.625 (40.625)
# valid_accuracy 35.740
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [67][0/77]	Loss 0.3495 (0.3495)	Accuracy 87.500 (87.500)
# Epoch: [67][50/77]	Loss 0.3026 (0.2949)	Accuracy 82.812 (89.124)
# train_accuracy 88.949
# Test: [0/40]	Loss 2.8284 (2.8284)	Accuracy 46.094 (46.094)
# valid_accuracy 42.100
# Test: [0/40]	Loss 3.0540 (3.0540)	Accuracy 30.469 (30.469)
# valid_accuracy 36.320
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [68][0/77]	Loss 0.2583 (0.2583)	Accuracy 92.188 (92.188)
# Epoch: [68][50/77]	Loss 0.1932 (0.2674)	Accuracy 92.188 (89.323)
# train_accuracy 89.133
# Test: [0/40]	Loss 2.0171 (2.0171)	Accuracy 53.906 (53.906)
# valid_accuracy 43.060
# Test: [0/40]	Loss 2.3435 (2.3435)	Accuracy 43.750 (43.750)
# valid_accuracy 37.400
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [69][0/77]	Loss 0.2661 (0.2661)	Accuracy 90.625 (90.625)
# Epoch: [69][50/77]	Loss 0.2385 (0.2560)	Accuracy 92.188 (89.246)
# train_accuracy 89.480
# Test: [0/40]	Loss 2.3948 (2.3948)	Accuracy 55.469 (55.469)
# valid_accuracy 44.500
# Test: [0/40]	Loss 2.7355 (2.7355)	Accuracy 39.844 (39.844)
# valid_accuracy 34.400
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [70][0/77]	Loss 0.2787 (0.2787)	Accuracy 84.375 (84.375)
# Epoch: [70][50/77]	Loss 0.2977 (0.2362)	Accuracy 89.844 (89.706)
# train_accuracy 89.857
# Test: [0/40]	Loss 3.4534 (3.4534)	Accuracy 39.062 (39.062)
# valid_accuracy 40.240
# Test: [0/40]	Loss 2.9854 (2.9854)	Accuracy 37.500 (37.500)
# valid_accuracy 36.700
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [71][0/77]	Loss 0.1855 (0.1855)	Accuracy 92.188 (92.188)
# Epoch: [71][50/77]	Loss 0.1822 (0.2301)	Accuracy 91.406 (89.568)
# train_accuracy 89.776
# Test: [0/40]	Loss 2.5720 (2.5720)	Accuracy 50.781 (50.781)
# valid_accuracy 41.740
# Test: [0/40]	Loss 2.7654 (2.7654)	Accuracy 41.406 (41.406)
# valid_accuracy 36.720
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [72][0/77]	Loss 0.2554 (0.2554)	Accuracy 90.625 (90.625)
# Epoch: [72][50/77]	Loss 0.1893 (0.2294)	Accuracy 90.625 (89.997)
# train_accuracy 90.398
# Test: [0/40]	Loss 2.5530 (2.5530)	Accuracy 52.344 (52.344)
# valid_accuracy 43.200
# Test: [0/40]	Loss 2.8674 (2.8674)	Accuracy 39.844 (39.844)
# valid_accuracy 36.760
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [73][0/77]	Loss 0.2344 (0.2344)	Accuracy 88.281 (88.281)
# Epoch: [73][50/77]	Loss 0.1322 (0.2166)	Accuracy 96.094 (90.119)
# train_accuracy 90.337
# Test: [0/40]	Loss 2.8977 (2.8977)	Accuracy 56.250 (56.250)
# valid_accuracy 43.800
# Test: [0/40]	Loss 2.9779 (2.9779)	Accuracy 40.625 (40.625)
# valid_accuracy 37.520
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [74][0/77]	Loss 0.1965 (0.1965)	Accuracy 90.625 (90.625)
# Epoch: [74][50/77]	Loss 0.1951 (0.1933)	Accuracy 89.062 (90.947)
# train_accuracy 90.755
# Test: [0/40]	Loss 3.2981 (3.2981)	Accuracy 51.562 (51.562)
# valid_accuracy 41.940
# Test: [0/40]	Loss 3.3829 (3.3829)	Accuracy 37.500 (37.500)
# valid_accuracy 37.280
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [75][0/77]	Loss 0.2031 (0.2031)	Accuracy 91.406 (91.406)
# Epoch: [75][50/77]	Loss 0.1802 (0.1930)	Accuracy 89.844 (90.472)
# train_accuracy 90.786
# Test: [0/40]	Loss 3.0424 (3.0424)	Accuracy 45.312 (45.312)
# valid_accuracy 40.800
# Test: [0/40]	Loss 2.7829 (2.7829)	Accuracy 44.531 (44.531)
# valid_accuracy 38.620
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [76][0/77]	Loss 0.1367 (0.1367)	Accuracy 93.750 (93.750)
# Epoch: [76][50/77]	Loss 0.1587 (0.1839)	Accuracy 92.188 (91.314)
# train_accuracy 91.194
# Test: [0/40]	Loss 4.1425 (4.1425)	Accuracy 28.125 (28.125)
# valid_accuracy 32.960
# Test: [0/40]	Loss 3.2156 (3.2156)	Accuracy 38.281 (38.281)
# valid_accuracy 36.280
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [77][0/77]	Loss 0.2371 (0.2371)	Accuracy 90.625 (90.625)
# Epoch: [77][50/77]	Loss 0.1316 (0.1757)	Accuracy 96.094 (91.207)
# train_accuracy 91.327
# Test: [0/40]	Loss 3.1040 (3.1040)	Accuracy 55.469 (55.469)
# valid_accuracy 41.000
# Test: [0/40]	Loss 3.1611 (3.1611)	Accuracy 42.969 (42.969)
# valid_accuracy 38.320
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [78][0/77]	Loss 0.1833 (0.1833)	Accuracy 90.625 (90.625)
# Epoch: [78][50/77]	Loss 0.1755 (0.1843)	Accuracy 92.188 (91.360)
# train_accuracy 91.143
# Test: [0/40]	Loss 2.9813 (2.9813)	Accuracy 56.250 (56.250)
# valid_accuracy 42.520
# Test: [0/40]	Loss 3.1168 (3.1168)	Accuracy 39.062 (39.062)
# valid_accuracy 39.560
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [79][0/77]	Loss 0.1340 (0.1340)	Accuracy 93.750 (93.750)
# Epoch: [79][50/77]	Loss 0.1339 (0.1740)	Accuracy 94.531 (91.039)
# train_accuracy 91.367
# Test: [0/40]	Loss 2.5683 (2.5683)	Accuracy 57.812 (57.812)
# valid_accuracy 40.300
# Test: [0/40]	Loss 2.6401 (2.6401)	Accuracy 47.656 (47.656)
# valid_accuracy 39.440
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [80][0/77]	Loss 0.1310 (0.1310)	Accuracy 92.188 (92.188)
# Epoch: [80][50/77]	Loss 0.1805 (0.1511)	Accuracy 92.188 (92.019)
# train_accuracy 92.255
# Test: [0/40]	Loss 3.1472 (3.1472)	Accuracy 50.000 (50.000)
# valid_accuracy 39.360
# Test: [0/40]	Loss 2.9729 (2.9729)	Accuracy 42.188 (42.188)
# valid_accuracy 37.580
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [81][0/77]	Loss 0.1687 (0.1687)	Accuracy 86.719 (86.719)
# Epoch: [81][50/77]	Loss 0.1112 (0.1431)	Accuracy 92.188 (92.341)
# train_accuracy 92.418
# Test: [0/40]	Loss 3.0635 (3.0635)	Accuracy 52.344 (52.344)
# valid_accuracy 40.000
# Test: [0/40]	Loss 2.9384 (2.9384)	Accuracy 44.531 (44.531)
# valid_accuracy 37.880
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [82][0/77]	Loss 0.1587 (0.1587)	Accuracy 89.062 (89.062)
# Epoch: [82][50/77]	Loss 0.1453 (0.1430)	Accuracy 92.969 (92.203)
# train_accuracy 92.265
# Test: [0/40]	Loss 3.3205 (3.3205)	Accuracy 51.562 (51.562)
# valid_accuracy 40.720
# Test: [0/40]	Loss 3.1831 (3.1831)	Accuracy 42.188 (42.188)
# valid_accuracy 38.160
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [83][0/77]	Loss 0.1346 (0.1346)	Accuracy 91.406 (91.406)
# Epoch: [83][50/77]	Loss 0.1446 (0.1363)	Accuracy 89.844 (92.846)
# train_accuracy 92.714
# Test: [0/40]	Loss 3.2278 (3.2278)	Accuracy 50.781 (50.781)
# valid_accuracy 39.720
# Test: [0/40]	Loss 2.9108 (2.9108)	Accuracy 42.969 (42.969)
# valid_accuracy 38.500
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [84][0/77]	Loss 0.1448 (0.1448)	Accuracy 86.719 (86.719)
# Epoch: [84][50/77]	Loss 0.1450 (0.1392)	Accuracy 92.969 (92.448)
# train_accuracy 92.510
# Test: [0/40]	Loss 3.4597 (3.4597)	Accuracy 50.781 (50.781)
# valid_accuracy 39.700
# Test: [0/40]	Loss 3.0763 (3.0763)	Accuracy 41.406 (41.406)
# valid_accuracy 37.860
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [85][0/77]	Loss 0.1476 (0.1476)	Accuracy 96.094 (96.094)
# Epoch: [85][50/77]	Loss 0.1611 (0.1321)	Accuracy 92.969 (92.831)
# train_accuracy 92.643
# Test: [0/40]	Loss 3.4249 (3.4249)	Accuracy 48.438 (48.438)
# valid_accuracy 39.220
# Test: [0/40]	Loss 3.1336 (3.1336)	Accuracy 42.188 (42.188)
# valid_accuracy 38.460
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [86][0/77]	Loss 0.1330 (0.1330)	Accuracy 93.750 (93.750)
# Epoch: [86][50/77]	Loss 0.1996 (0.1363)	Accuracy 89.844 (92.754)
# train_accuracy 92.551
# Test: [0/40]	Loss 3.3648 (3.3648)	Accuracy 49.219 (49.219)
# valid_accuracy 39.200
# Test: [0/40]	Loss 3.1823 (3.1823)	Accuracy 42.188 (42.188)
# valid_accuracy 37.800
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [87][0/77]	Loss 0.3727 (0.3727)	Accuracy 93.750 (93.750)
# Epoch: [87][50/77]	Loss 0.1652 (0.1391)	Accuracy 86.719 (92.647)
# train_accuracy 92.847
# Test: [0/40]	Loss 3.4160 (3.4160)	Accuracy 42.188 (42.188)
# valid_accuracy 37.420
# Test: [0/40]	Loss 2.9530 (2.9530)	Accuracy 42.969 (42.969)
# valid_accuracy 37.940
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [88][0/77]	Loss 0.1146 (0.1146)	Accuracy 93.750 (93.750)
# Epoch: [88][50/77]	Loss 0.1342 (0.1309)	Accuracy 94.531 (93.183)
# train_accuracy 92.735
# Test: [0/40]	Loss 3.3589 (3.3589)	Accuracy 49.219 (49.219)
# valid_accuracy 39.120
# Test: [0/40]	Loss 3.1121 (3.1121)	Accuracy 41.406 (41.406)
# valid_accuracy 38.220
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [89][0/77]	Loss 0.1490 (0.1490)	Accuracy 92.188 (92.188)
# Epoch: [89][50/77]	Loss 0.1118 (0.1279)	Accuracy 94.531 (92.770)
# train_accuracy 92.704
# Test: [0/40]	Loss 3.6434 (3.6434)	Accuracy 42.188 (42.188)
# valid_accuracy 38.180
# Test: [0/40]	Loss 3.2124 (3.2124)	Accuracy 39.844 (39.844)
# valid_accuracy 37.720
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [90][0/77]	Loss 0.1273 (0.1273)	Accuracy 94.531 (94.531)
# Epoch: [90][50/77]	Loss 0.1476 (0.1271)	Accuracy 92.188 (93.091)
# train_accuracy 92.939
# Test: [0/40]	Loss 3.4928 (3.4928)	Accuracy 44.531 (44.531)
# valid_accuracy 38.560
# Test: [0/40]	Loss 3.1136 (3.1136)	Accuracy 40.625 (40.625)
# valid_accuracy 37.880
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [91][0/77]	Loss 0.1376 (0.1376)	Accuracy 92.969 (92.969)
# Epoch: [91][50/77]	Loss 0.1114 (0.1295)	Accuracy 95.312 (92.862)
# train_accuracy 92.847
# Test: [0/40]	Loss 3.4677 (3.4677)	Accuracy 50.781 (50.781)
# valid_accuracy 39.220
# Test: [0/40]	Loss 3.2095 (3.2095)	Accuracy 39.844 (39.844)
# valid_accuracy 37.800
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [92][0/77]	Loss 0.1510 (0.1510)	Accuracy 90.625 (90.625)
# Epoch: [92][50/77]	Loss 0.0924 (0.1289)	Accuracy 94.531 (93.153)
# train_accuracy 93.031
# Test: [0/40]	Loss 3.5536 (3.5536)	Accuracy 45.312 (45.312)
# valid_accuracy 38.780
# Test: [0/40]	Loss 3.3157 (3.3157)	Accuracy 36.719 (36.719)
# valid_accuracy 37.560
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [93][0/77]	Loss 0.2148 (0.2148)	Accuracy 89.062 (89.062)
# Epoch: [93][50/77]	Loss 0.0866 (0.1323)	Accuracy 96.875 (93.076)
# train_accuracy 92.939
# Test: [0/40]	Loss 3.7275 (3.7275)	Accuracy 39.844 (39.844)
# valid_accuracy 36.940
# Test: [0/40]	Loss 3.3146 (3.3146)	Accuracy 38.281 (38.281)
# valid_accuracy 37.280
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [94][0/77]	Loss 0.1145 (0.1145)	Accuracy 93.750 (93.750)
# Epoch: [94][50/77]	Loss 0.1753 (0.1310)	Accuracy 85.938 (92.601)
# train_accuracy 92.622
# Test: [0/40]	Loss 3.5138 (3.5138)	Accuracy 46.094 (46.094)
# valid_accuracy 39.060
# Test: [0/40]	Loss 3.2590 (3.2590)	Accuracy 39.844 (39.844)
# valid_accuracy 37.940
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [95][0/77]	Loss 0.1346 (0.1346)	Accuracy 89.844 (89.844)
# Epoch: [95][50/77]	Loss 0.1430 (0.1343)	Accuracy 91.406 (92.647)
# train_accuracy 92.796
# Test: [0/40]	Loss 3.1723 (3.1723)	Accuracy 53.906 (53.906)
# valid_accuracy 40.560
# Test: [0/40]	Loss 3.1239 (3.1239)	Accuracy 41.406 (41.406)
# valid_accuracy 39.080
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [96][0/77]	Loss 0.1466 (0.1466)	Accuracy 92.188 (92.188)
# Epoch: [96][50/77]	Loss 0.1005 (0.1270)	Accuracy 93.750 (93.214)
# train_accuracy 93.010
# Test: [0/40]	Loss 3.5401 (3.5401)	Accuracy 41.406 (41.406)
# valid_accuracy 37.120
# Test: [0/40]	Loss 3.2101 (3.2101)	Accuracy 39.844 (39.844)
# valid_accuracy 37.580
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [97][0/77]	Loss 0.0653 (0.0653)	Accuracy 98.438 (98.438)
# Epoch: [97][50/77]	Loss 0.1041 (0.1264)	Accuracy 92.188 (93.352)
# train_accuracy 93.296
# Test: [0/40]	Loss 3.2821 (3.2821)	Accuracy 48.438 (48.438)
# valid_accuracy 39.740
# Test: [0/40]	Loss 3.2113 (3.2113)	Accuracy 39.844 (39.844)
# valid_accuracy 38.020
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [98][0/77]	Loss 0.1085 (0.1085)	Accuracy 95.312 (95.312)
# Epoch: [98][50/77]	Loss 0.1341 (0.1287)	Accuracy 92.188 (92.770)
# train_accuracy 92.878
# Test: [0/40]	Loss 3.4136 (3.4136)	Accuracy 49.219 (49.219)
# valid_accuracy 39.060
# Test: [0/40]	Loss 3.2315 (3.2315)	Accuracy 39.062 (39.062)
# valid_accuracy 37.700
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [99][0/77]	Loss 0.1341 (0.1341)	Accuracy 96.094 (96.094)
# Epoch: [99][50/77]	Loss 0.1251 (0.1240)	Accuracy 90.625 (93.428)
# train_accuracy 93.255
# Test: [0/40]	Loss 4.0092 (4.0092)	Accuracy 32.812 (32.812)
# valid_accuracy 36.420
# Test: [0/40]	Loss 3.3445 (3.3445)	Accuracy 36.719 (36.719)
# valid_accuracy 37.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [100][0/77]	Loss 0.0848 (0.0848)	Accuracy 96.094 (96.094)
# Epoch: [100][50/77]	Loss 0.0702 (0.1242)	Accuracy 98.438 (92.907)
# train_accuracy 92.816
# Test: [0/40]	Loss 3.4561 (3.4561)	Accuracy 42.188 (42.188)
# valid_accuracy 38.280
# Test: [0/40]	Loss 3.1780 (3.1780)	Accuracy 39.844 (39.844)
# valid_accuracy 37.880
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [101][0/77]	Loss 0.1377 (0.1377)	Accuracy 91.406 (91.406)
# Epoch: [101][50/77]	Loss 0.0928 (0.1249)	Accuracy 96.094 (93.244)
# train_accuracy 93.265
# Test: [0/40]	Loss 3.4504 (3.4504)	Accuracy 46.094 (46.094)
# valid_accuracy 38.760
# Test: [0/40]	Loss 3.2567 (3.2567)	Accuracy 39.844 (39.844)
# valid_accuracy 38.320
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [102][0/77]	Loss 0.1591 (0.1591)	Accuracy 92.188 (92.188)
# Epoch: [102][50/77]	Loss 0.1420 (0.1178)	Accuracy 93.750 (93.290)
# train_accuracy 93.214
# Test: [0/40]	Loss 3.7160 (3.7160)	Accuracy 39.062 (39.062)
# valid_accuracy 36.400
# Test: [0/40]	Loss 3.3473 (3.3473)	Accuracy 38.281 (38.281)
# valid_accuracy 37.240
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [103][0/77]	Loss 0.1573 (0.1573)	Accuracy 91.406 (91.406)
# Epoch: [103][50/77]	Loss 0.0826 (0.1292)	Accuracy 95.312 (92.555)
# train_accuracy 92.837
# Test: [0/40]	Loss 3.6142 (3.6142)	Accuracy 44.531 (44.531)
# valid_accuracy 37.680
# Test: [0/40]	Loss 3.3216 (3.3216)	Accuracy 39.844 (39.844)
# valid_accuracy 37.420
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [104][0/77]	Loss 0.1007 (0.1007)	Accuracy 95.312 (95.312)
# Epoch: [104][50/77]	Loss 0.1004 (0.1245)	Accuracy 93.750 (93.122)
# train_accuracy 93.184
# Test: [0/40]	Loss 3.2900 (3.2900)	Accuracy 50.781 (50.781)
# valid_accuracy 38.900
# Test: [0/40]	Loss 3.1360 (3.1360)	Accuracy 41.406 (41.406)
# valid_accuracy 38.340
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [105][0/77]	Loss 0.1156 (0.1156)	Accuracy 94.531 (94.531)
# Epoch: [105][50/77]	Loss 0.1011 (0.1228)	Accuracy 89.844 (93.581)
# train_accuracy 93.439
# Test: [0/40]	Loss 3.6079 (3.6079)	Accuracy 42.188 (42.188)
# valid_accuracy 38.040
# Test: [0/40]	Loss 3.4015 (3.4015)	Accuracy 39.062 (39.062)
# valid_accuracy 38.060
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [106][0/77]	Loss 0.1132 (0.1132)	Accuracy 93.750 (93.750)
# Epoch: [106][50/77]	Loss 0.1778 (0.1183)	Accuracy 92.969 (93.627)
# train_accuracy 93.439
# Test: [0/40]	Loss 3.4278 (3.4278)	Accuracy 48.438 (48.438)
# valid_accuracy 38.980
# Test: [0/40]	Loss 3.2836 (3.2836)	Accuracy 39.844 (39.844)
# valid_accuracy 37.580
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [107][0/77]	Loss 0.1265 (0.1265)	Accuracy 92.969 (92.969)
# Epoch: [107][50/77]	Loss 0.0676 (0.1243)	Accuracy 97.656 (92.647)
# train_accuracy 93.112
# Test: [0/40]	Loss 3.8814 (3.8814)	Accuracy 32.031 (32.031)
# valid_accuracy 36.000
# Test: [0/40]	Loss 3.4053 (3.4053)	Accuracy 39.062 (39.062)
# valid_accuracy 36.760
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [108][0/77]	Loss 0.1375 (0.1375)	Accuracy 91.406 (91.406)
# Epoch: [108][50/77]	Loss 0.1314 (0.1262)	Accuracy 94.531 (93.474)
# train_accuracy 93.327
# Test: [0/40]	Loss 3.6798 (3.6798)	Accuracy 47.656 (47.656)
# valid_accuracy 36.700
# Test: [0/40]	Loss 3.2292 (3.2292)	Accuracy 40.625 (40.625)
# valid_accuracy 37.620
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [109][0/77]	Loss 0.1858 (0.1858)	Accuracy 92.188 (92.188)
# Epoch: [109][50/77]	Loss 0.1291 (0.1265)	Accuracy 91.406 (93.015)
# train_accuracy 93.173
# Test: [0/40]	Loss 3.2031 (3.2031)	Accuracy 49.219 (49.219)
# valid_accuracy 39.260
# Test: [0/40]	Loss 3.0872 (3.0872)	Accuracy 41.406 (41.406)
# valid_accuracy 38.540
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [110][0/77]	Loss 0.1035 (0.1035)	Accuracy 92.188 (92.188)
# Epoch: [110][50/77]	Loss 0.1094 (0.1186)	Accuracy 94.531 (93.290)
# train_accuracy 93.327
# Test: [0/40]	Loss 4.0275 (4.0275)	Accuracy 32.812 (32.812)
# valid_accuracy 33.800
# Test: [0/40]	Loss 3.1133 (3.1133)	Accuracy 42.188 (42.188)
# valid_accuracy 37.840
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [111][0/77]	Loss 0.1061 (0.1061)	Accuracy 95.312 (95.312)
# Epoch: [111][50/77]	Loss 0.1452 (0.1229)	Accuracy 92.969 (93.750)
# train_accuracy 93.592
# Test: [0/40]	Loss 3.6869 (3.6869)	Accuracy 39.844 (39.844)
# valid_accuracy 37.560
# Test: [0/40]	Loss 3.2549 (3.2549)	Accuracy 40.625 (40.625)
# valid_accuracy 38.480
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [112][0/77]	Loss 0.1444 (0.1444)	Accuracy 90.625 (90.625)
# Epoch: [112][50/77]	Loss 0.1323 (0.1121)	Accuracy 92.969 (93.336)
# train_accuracy 93.265
# Test: [0/40]	Loss 3.7408 (3.7408)	Accuracy 37.500 (37.500)
# valid_accuracy 36.660
# Test: [0/40]	Loss 3.3223 (3.3223)	Accuracy 40.625 (40.625)
# valid_accuracy 37.540
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [113][0/77]	Loss 0.1505 (0.1505)	Accuracy 92.969 (92.969)
# Epoch: [113][50/77]	Loss 0.1333 (0.1190)	Accuracy 87.500 (93.321)
# train_accuracy 93.347
# Test: [0/40]	Loss 3.1752 (3.1752)	Accuracy 51.562 (51.562)
# valid_accuracy 39.820
# Test: [0/40]	Loss 3.1301 (3.1301)	Accuracy 42.188 (42.188)
# valid_accuracy 38.440
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [114][0/77]	Loss 0.0659 (0.0659)	Accuracy 96.875 (96.875)
# Epoch: [114][50/77]	Loss 0.0906 (0.1204)	Accuracy 92.188 (93.490)
# train_accuracy 93.357
# Test: [0/40]	Loss 3.5707 (3.5707)	Accuracy 40.625 (40.625)
# valid_accuracy 37.540
# Test: [0/40]	Loss 3.1783 (3.1783)	Accuracy 41.406 (41.406)
# valid_accuracy 38.400
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [115][0/77]	Loss 0.1240 (0.1240)	Accuracy 93.750 (93.750)
# Epoch: [115][50/77]	Loss 0.1434 (0.1153)	Accuracy 88.281 (93.765)
# train_accuracy 93.694
# Test: [0/40]	Loss 3.7695 (3.7695)	Accuracy 39.844 (39.844)
# valid_accuracy 37.860
# Test: [0/40]	Loss 3.3967 (3.3967)	Accuracy 39.844 (39.844)
# valid_accuracy 37.880
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [116][0/77]	Loss 0.0736 (0.0736)	Accuracy 93.750 (93.750)
# Epoch: [116][50/77]	Loss 0.0774 (0.1141)	Accuracy 96.094 (93.520)
# train_accuracy 93.327
# Test: [0/40]	Loss 3.5515 (3.5515)	Accuracy 45.312 (45.312)
# valid_accuracy 39.380
# Test: [0/40]	Loss 3.3418 (3.3418)	Accuracy 37.500 (37.500)
# valid_accuracy 38.100
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [117][0/77]	Loss 0.1396 (0.1396)	Accuracy 89.062 (89.062)
# Epoch: [117][50/77]	Loss 0.1347 (0.1165)	Accuracy 93.750 (93.520)
# train_accuracy 93.347
# Test: [0/40]	Loss 3.1988 (3.1988)	Accuracy 48.438 (48.438)
# valid_accuracy 39.080
# Test: [0/40]	Loss 3.0723 (3.0723)	Accuracy 42.969 (42.969)
# valid_accuracy 38.480
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [118][0/77]	Loss 0.0794 (0.0794)	Accuracy 95.312 (95.312)
# Epoch: [118][50/77]	Loss 0.1175 (0.1083)	Accuracy 92.969 (94.026)
# train_accuracy 93.755
# Test: [0/40]	Loss 3.7493 (3.7493)	Accuracy 41.406 (41.406)
# valid_accuracy 37.900
# Test: [0/40]	Loss 3.4706 (3.4706)	Accuracy 39.062 (39.062)
# valid_accuracy 37.520
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [119][0/77]	Loss 0.0911 (0.0911)	Accuracy 96.094 (96.094)
# Epoch: [119][50/77]	Loss 0.1656 (0.1194)	Accuracy 97.656 (93.413)
# train_accuracy 93.449
# Test: [0/40]	Loss 3.4798 (3.4798)	Accuracy 44.531 (44.531)
# valid_accuracy 38.680
# Test: [0/40]	Loss 3.3220 (3.3220)	Accuracy 40.625 (40.625)
# valid_accuracy 38.360
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [120][0/77]	Loss 0.1263 (0.1263)	Accuracy 93.750 (93.750)
# Epoch: [120][50/77]	Loss 0.0966 (0.1101)	Accuracy 95.312 (93.811)
# train_accuracy 93.571
# Test: [0/40]	Loss 3.1064 (3.1064)	Accuracy 49.219 (49.219)
# valid_accuracy 38.420
# Test: [0/40]	Loss 2.8841 (2.8841)	Accuracy 46.875 (46.875)
# ...
# valid_accuracy 38.280
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [161][0/77]	Loss 0.0909 (0.0909)	Accuracy 92.188 (92.188)
# Epoch: [161][50/77]	Loss 0.0952 (0.0934)	Accuracy 92.969 (94.991)
# train_accuracy 95.031
# Test: [0/40]	Loss 3.6468 (3.6468)	Accuracy 39.844 (39.844)
# valid_accuracy 38.780
# Test: [0/40]	Loss 3.2943 (3.2943)	Accuracy 40.625 (40.625)
# valid_accuracy 39.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [162][0/77]	Loss 0.0803 (0.0803)	Accuracy 93.750 (93.750)
# Epoch: [162][50/77]	Loss 0.0840 (0.0887)	Accuracy 96.094 (94.975)
# train_accuracy 94.980
# Test: [0/40]	Loss 3.7442 (3.7442)	Accuracy 40.625 (40.625)
# valid_accuracy 37.940
# Test: [0/40]	Loss 3.4370 (3.4370)	Accuracy 41.406 (41.406)
# valid_accuracy 38.000
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [163][0/77]	Loss 0.0687 (0.0687)	Accuracy 97.656 (97.656)
# Epoch: [163][50/77]	Loss 0.0899 (0.0923)	Accuracy 97.656 (95.067)
# train_accuracy 95.122
# Test: [0/40]	Loss 3.6180 (3.6180)	Accuracy 45.312 (45.312)
# valid_accuracy 39.120
# Test: [0/40]	Loss 3.3550 (3.3550)	Accuracy 42.969 (42.969)
# valid_accuracy 38.760
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [164][0/77]	Loss 0.0547 (0.0547)	Accuracy 98.438 (98.438)
# Epoch: [164][50/77]	Loss 0.0848 (0.0906)	Accuracy 94.531 (95.067)
# train_accuracy 95.020
# Test: [0/40]	Loss 3.8574 (3.8574)	Accuracy 39.062 (39.062)
# valid_accuracy 38.820
# Test: [0/40]	Loss 3.6541 (3.6541)	Accuracy 36.719 (36.719)
# valid_accuracy 38.660
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [165][0/77]	Loss 0.0349 (0.0349)	Accuracy 98.438 (98.438)
# Epoch: [165][50/77]	Loss 0.1022 (0.0926)	Accuracy 92.969 (94.715)
# train_accuracy 94.888
# Test: [0/40]	Loss 3.7140 (3.7140)	Accuracy 41.406 (41.406)
# valid_accuracy 36.440
# Test: [0/40]	Loss 3.4086 (3.4086)	Accuracy 40.625 (40.625)
# valid_accuracy 37.820
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [166][0/77]	Loss 0.0653 (0.0653)	Accuracy 94.531 (94.531)
# Epoch: [166][50/77]	Loss 0.0740 (0.0908)	Accuracy 94.531 (94.930)
# train_accuracy 94.837
# Test: [0/40]	Loss 3.8663 (3.8663)	Accuracy 36.719 (36.719)
# valid_accuracy 36.520
# Test: [0/40]	Loss 3.3130 (3.3130)	Accuracy 42.969 (42.969)
# valid_accuracy 38.300
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [167][0/77]	Loss 0.0771 (0.0771)	Accuracy 97.656 (97.656)
# Epoch: [167][50/77]	Loss 0.0698 (0.0913)	Accuracy 96.875 (94.853)
# train_accuracy 94.827
# Test: [0/40]	Loss 3.8601 (3.8601)	Accuracy 38.281 (38.281)
# valid_accuracy 37.480
# Test: [0/40]	Loss 3.5525 (3.5525)	Accuracy 42.188 (42.188)
# valid_accuracy 38.620
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [168][0/77]	Loss 0.1312 (0.1312)	Accuracy 91.406 (91.406)
# Epoch: [168][50/77]	Loss 0.0616 (0.0921)	Accuracy 96.875 (95.343)
# train_accuracy 95.459
# Test: [0/40]	Loss 3.9344 (3.9344)	Accuracy 34.375 (34.375)
# valid_accuracy 38.080
# Test: [0/40]	Loss 3.6457 (3.6457)	Accuracy 37.500 (37.500)
# valid_accuracy 38.220
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [169][0/77]	Loss 0.0642 (0.0642)	Accuracy 98.438 (98.438)
# Epoch: [169][50/77]	Loss 0.1022 (0.0887)	Accuracy 95.312 (94.853)
# train_accuracy 94.837
# Test: [0/40]	Loss 4.0303 (4.0303)	Accuracy 33.594 (33.594)
# valid_accuracy 36.640
# Test: [0/40]	Loss 3.7534 (3.7534)	Accuracy 36.719 (36.719)
# valid_accuracy 37.760
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [170][0/77]	Loss 0.0685 (0.0685)	Accuracy 95.312 (95.312)
# Epoch: [170][50/77]	Loss 0.0902 (0.0844)	Accuracy 97.656 (95.343)
# train_accuracy 95.255
# Test: [0/40]	Loss 3.9033 (3.9033)	Accuracy 35.938 (35.938)
# valid_accuracy 37.760
# Test: [0/40]	Loss 3.5932 (3.5932)	Accuracy 38.281 (38.281)
# valid_accuracy 38.280
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [171][0/77]	Loss 0.1008 (0.1008)	Accuracy 91.406 (91.406)
# Epoch: [171][50/77]	Loss 0.0785 (0.0909)	Accuracy 94.531 (94.730)
# train_accuracy 94.847
# Test: [0/40]	Loss 3.6801 (3.6801)	Accuracy 37.500 (37.500)
# valid_accuracy 37.500
# Test: [0/40]	Loss 3.4597 (3.4597)	Accuracy 38.281 (38.281)
# valid_accuracy 38.100
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [172][0/77]	Loss 0.1330 (0.1330)	Accuracy 92.188 (92.188)
# Epoch: [172][50/77]	Loss 0.0853 (0.0929)	Accuracy 92.188 (94.623)
# train_accuracy 94.786
# Test: [0/40]	Loss 3.6688 (3.6688)	Accuracy 37.500 (37.500)
# valid_accuracy 37.220
# Test: [0/40]	Loss 3.3665 (3.3665)	Accuracy 38.281 (38.281)
# valid_accuracy 38.400
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [173][0/77]	Loss 0.0855 (0.0855)	Accuracy 96.094 (96.094)
# Epoch: [173][50/77]	Loss 0.0553 (0.0853)	Accuracy 96.875 (95.374)
# train_accuracy 95.143
# Test: [0/40]	Loss 3.8866 (3.8866)	Accuracy 35.938 (35.938)
# valid_accuracy 36.660
# Test: [0/40]	Loss 3.5682 (3.5682)	Accuracy 39.844 (39.844)
# valid_accuracy 38.540
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [174][0/77]	Loss 0.1133 (0.1133)	Accuracy 91.406 (91.406)
# Epoch: [174][50/77]	Loss 0.1029 (0.0874)	Accuracy 93.750 (95.542)
# train_accuracy 95.561
# Test: [0/40]	Loss 3.9020 (3.9020)	Accuracy 38.281 (38.281)
# valid_accuracy 36.540
# Test: [0/40]	Loss 3.5326 (3.5326)	Accuracy 36.719 (36.719)
# valid_accuracy 37.860
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [175][0/77]	Loss 0.0431 (0.0431)	Accuracy 99.219 (99.219)
# Epoch: [175][50/77]	Loss 0.1174 (0.0844)	Accuracy 93.750 (95.665)
# train_accuracy 95.469
# Test: [0/40]	Loss 4.1821 (4.1821)	Accuracy 35.156 (35.156)
# valid_accuracy 38.040
# Test: [0/40]	Loss 3.7515 (3.7515)	Accuracy 35.156 (35.156)
# valid_accuracy 38.140
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [176][0/77]	Loss 0.0825 (0.0825)	Accuracy 93.750 (93.750)
# Epoch: [176][50/77]	Loss 0.1047 (0.0862)	Accuracy 91.406 (95.297)
# train_accuracy 95.388
# Test: [0/40]	Loss 3.7034 (3.7034)	Accuracy 42.969 (42.969)
# valid_accuracy 37.440
# Test: [0/40]	Loss 3.3726 (3.3726)	Accuracy 42.188 (42.188)
# valid_accuracy 38.880
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [177][0/77]	Loss 0.0984 (0.0984)	Accuracy 93.750 (93.750)
# Epoch: [177][50/77]	Loss 0.0765 (0.0863)	Accuracy 96.094 (95.175)
# train_accuracy 95.367
# Test: [0/40]	Loss 4.5757 (4.5757)	Accuracy 32.812 (32.812)
# valid_accuracy 36.700
# Test: [0/40]	Loss 4.0174 (4.0174)	Accuracy 35.156 (35.156)
# valid_accuracy 37.780
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [178][0/77]	Loss 0.0661 (0.0661)	Accuracy 98.438 (98.438)
# Epoch: [178][50/77]	Loss 0.0744 (0.0832)	Accuracy 96.094 (95.129)
# train_accuracy 95.163
# Test: [0/40]	Loss 3.7726 (3.7726)	Accuracy 39.844 (39.844)
# valid_accuracy 37.560
# Test: [0/40]	Loss 3.6613 (3.6613)	Accuracy 35.938 (35.938)
# valid_accuracy 37.600
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [179][0/77]	Loss 0.0680 (0.0680)	Accuracy 94.531 (94.531)
# Epoch: [179][50/77]	Loss 0.0760 (0.0848)	Accuracy 96.875 (95.328)
# train_accuracy 95.398
# Test: [0/40]	Loss 3.9382 (3.9382)	Accuracy 37.500 (37.500)
# valid_accuracy 36.980
# Test: [0/40]	Loss 3.5947 (3.5947)	Accuracy 36.719 (36.719)
# valid_accuracy 37.880
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [180][0/77]	Loss 0.0650 (0.0650)	Accuracy 98.438 (98.438)
# Epoch: [180][50/77]	Loss 0.0893 (0.0819)	Accuracy 92.969 (95.282)
# train_accuracy 95.255
# Test: [0/40]	Loss 3.5378 (3.5378)	Accuracy 45.312 (45.312)
# valid_accuracy 39.520
# Test: [0/40]	Loss 3.4922 (3.4922)	Accuracy 40.625 (40.625)
# valid_accuracy 38.980
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [181][0/77]	Loss 0.0898 (0.0898)	Accuracy 93.750 (93.750)
# Epoch: [181][50/77]	Loss 0.0433 (0.0790)	Accuracy 99.219 (95.573)
# train_accuracy 95.561
# Test: [0/40]	Loss 3.7111 (3.7111)	Accuracy 41.406 (41.406)
# valid_accuracy 37.100
# Test: [0/40]	Loss 3.4757 (3.4757)	Accuracy 40.625 (40.625)
# valid_accuracy 38.660
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [182][0/77]	Loss 0.0842 (0.0842)	Accuracy 96.875 (96.875)
# Epoch: [182][50/77]	Loss 0.0595 (0.0766)	Accuracy 95.312 (95.634)
# train_accuracy 95.633
# Test: [0/40]	Loss 3.7545 (3.7545)	Accuracy 38.281 (38.281)
# valid_accuracy 37.920
# Test: [0/40]	Loss 3.4807 (3.4807)	Accuracy 38.281 (38.281)
# valid_accuracy 38.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [183][0/77]	Loss 0.0810 (0.0810)	Accuracy 95.312 (95.312)
# Epoch: [183][50/77]	Loss 0.1035 (0.0795)	Accuracy 96.875 (95.680)
# train_accuracy 95.622
# Test: [0/40]	Loss 3.9086 (3.9086)	Accuracy 37.500 (37.500)
# valid_accuracy 38.280
# Test: [0/40]	Loss 3.6091 (3.6091)	Accuracy 37.500 (37.500)
# valid_accuracy 38.180
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [184][0/77]	Loss 0.1061 (0.1061)	Accuracy 95.312 (95.312)
# Epoch: [184][50/77]	Loss 0.0769 (0.0832)	Accuracy 95.312 (95.267)
# train_accuracy 95.541
# Test: [0/40]	Loss 3.5988 (3.5988)	Accuracy 42.969 (42.969)
# valid_accuracy 40.320
# Test: [0/40]	Loss 3.6436 (3.6436)	Accuracy 37.500 (37.500)
# valid_accuracy 38.440
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [185][0/77]	Loss 0.1253 (0.1253)	Accuracy 96.094 (96.094)
# Epoch: [185][50/77]	Loss 0.0922 (0.0772)	Accuracy 94.531 (95.542)
# train_accuracy 95.561
# Test: [0/40]	Loss 4.2396 (4.2396)	Accuracy 32.031 (32.031)
# valid_accuracy 34.200
# Test: [0/40]	Loss 3.8401 (3.8401)	Accuracy 37.500 (37.500)
# valid_accuracy 37.540
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [186][0/77]	Loss 0.0458 (0.0458)	Accuracy 96.875 (96.875)
# Epoch: [186][50/77]	Loss 0.1038 (0.0757)	Accuracy 94.531 (96.017)
# train_accuracy 95.837
# Test: [0/40]	Loss 3.6588 (3.6588)	Accuracy 44.531 (44.531)
# valid_accuracy 37.740
# Test: [0/40]	Loss 3.4348 (3.4348)	Accuracy 40.625 (40.625)
# valid_accuracy 38.480
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [187][0/77]	Loss 0.0741 (0.0741)	Accuracy 100.000 (100.000)
# Epoch: [187][50/77]	Loss 0.0672 (0.0805)	Accuracy 96.094 (95.665)
# train_accuracy 95.531
# Test: [0/40]	Loss 3.4170 (3.4170)	Accuracy 46.094 (46.094)
# valid_accuracy 38.340
# Test: [0/40]	Loss 3.3531 (3.3531)	Accuracy 43.750 (43.750)
# valid_accuracy 39.060
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [188][0/77]	Loss 0.0669 (0.0669)	Accuracy 96.875 (96.875)
# Epoch: [188][50/77]	Loss 0.0945 (0.0761)	Accuracy 92.188 (95.588)
# train_accuracy 95.592
# Test: [0/40]	Loss 3.4048 (3.4048)	Accuracy 46.094 (46.094)
# valid_accuracy 39.760
# Test: [0/40]	Loss 3.4278 (3.4278)	Accuracy 43.750 (43.750)
# valid_accuracy 39.240
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [189][0/77]	Loss 0.1150 (0.1150)	Accuracy 96.875 (96.875)
# Epoch: [189][50/77]	Loss 0.1044 (0.0785)	Accuracy 92.188 (95.573)
# train_accuracy 95.592
# Test: [0/40]	Loss 3.6681 (3.6681)	Accuracy 41.406 (41.406)
# valid_accuracy 39.140
# Test: [0/40]	Loss 3.6086 (3.6086)	Accuracy 38.281 (38.281)
# valid_accuracy 39.180
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [190][0/77]	Loss 0.1340 (0.1340)	Accuracy 91.406 (91.406)
# Epoch: [190][50/77]	Loss 0.0751 (0.0757)	Accuracy 94.531 (95.695)
# train_accuracy 95.694
# Test: [0/40]	Loss 3.6953 (3.6953)	Accuracy 39.844 (39.844)
# valid_accuracy 37.160
# Test: [0/40]	Loss 3.5536 (3.5536)	Accuracy 38.281 (38.281)
# valid_accuracy 37.660
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [191][0/77]	Loss 0.0434 (0.0434)	Accuracy 98.438 (98.438)
# Epoch: [191][50/77]	Loss 0.0560 (0.0695)	Accuracy 96.094 (96.140)
# train_accuracy 95.929
# Test: [0/40]	Loss 3.6685 (3.6685)	Accuracy 44.531 (44.531)
# valid_accuracy 39.860
# Test: [0/40]	Loss 3.5261 (3.5261)	Accuracy 41.406 (41.406)
# valid_accuracy 39.180
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [192][0/77]	Loss 0.0997 (0.0997)	Accuracy 93.750 (93.750)
# Epoch: [192][50/77]	Loss 0.0578 (0.0744)	Accuracy 97.656 (95.910)
# train_accuracy 95.847
# Test: [0/40]	Loss 4.0159 (4.0159)	Accuracy 35.938 (35.938)
# valid_accuracy 35.940
# Test: [0/40]	Loss 3.6860 (3.6860)	Accuracy 36.719 (36.719)
# valid_accuracy 38.280
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [193][0/77]	Loss 0.0563 (0.0563)	Accuracy 98.438 (98.438)
# Epoch: [193][50/77]	Loss 0.1268 (0.0753)	Accuracy 90.625 (95.833)
# train_accuracy 95.847
# Test: [0/40]	Loss 3.4254 (3.4254)	Accuracy 43.750 (43.750)
# valid_accuracy 38.060
# Test: [0/40]	Loss 3.4520 (3.4520)	Accuracy 39.844 (39.844)
# valid_accuracy 38.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [194][0/77]	Loss 0.0982 (0.0982)	Accuracy 92.969 (92.969)
# Epoch: [194][50/77]	Loss 0.0817 (0.0748)	Accuracy 94.531 (95.895)
# train_accuracy 96.041
# Test: [0/40]	Loss 3.7800 (3.7800)	Accuracy 38.281 (38.281)
# valid_accuracy 35.740
# Test: [0/40]	Loss 3.6628 (3.6628)	Accuracy 37.500 (37.500)
# valid_accuracy 37.820
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [195][0/77]	Loss 0.0972 (0.0972)	Accuracy 94.531 (94.531)
# Epoch: [195][50/77]	Loss 0.0693 (0.0715)	Accuracy 95.312 (95.803)
# train_accuracy 95.990
# Test: [0/40]	Loss 4.1777 (4.1777)	Accuracy 32.812 (32.812)
# valid_accuracy 37.160
# Test: [0/40]	Loss 3.8119 (3.8119)	Accuracy 35.938 (35.938)
# valid_accuracy 37.980
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [196][0/77]	Loss 0.0532 (0.0532)	Accuracy 97.656 (97.656)
# Epoch: [196][50/77]	Loss 0.1451 (0.0732)	Accuracy 93.750 (95.925)
# train_accuracy 95.786
# Test: [0/40]	Loss 3.6541 (3.6541)	Accuracy 42.188 (42.188)
# valid_accuracy 38.620
# Test: [0/40]	Loss 3.7839 (3.7839)	Accuracy 39.844 (39.844)
# valid_accuracy 38.000
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [197][0/77]	Loss 0.0867 (0.0867)	Accuracy 92.188 (92.188)
# Epoch: [197][50/77]	Loss 0.0461 (0.0738)	Accuracy 96.875 (95.634)
# train_accuracy 95.918
# Test: [0/40]	Loss 3.7484 (3.7484)	Accuracy 37.500 (37.500)
# valid_accuracy 36.080
# Test: [0/40]	Loss 3.7528 (3.7528)	Accuracy 39.062 (39.062)
# valid_accuracy 37.900
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [198][0/77]	Loss 0.0844 (0.0844)	Accuracy 96.875 (96.875)
# Epoch: [198][50/77]	Loss 0.0598 (0.0711)	Accuracy 94.531 (96.078)
# train_accuracy 95.918
# Test: [0/40]	Loss 3.3297 (3.3297)	Accuracy 47.656 (47.656)
# valid_accuracy 39.280
# Test: [0/40]	Loss 3.3273 (3.3273)	Accuracy 43.750 (43.750)
# valid_accuracy 39.640
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [199][0/77]	Loss 0.0739 (0.0739)	Accuracy 93.750 (93.750)
# Epoch: [199][50/77]	Loss 0.0488 (0.0706)	Accuracy 97.656 (96.262)
# train_accuracy 96.245
# Test: [0/40]	Loss 3.8663 (3.8663)	Accuracy 39.844 (39.844)
# valid_accuracy 37.900
# Test: [0/40]	Loss 3.6694 (3.6694)	Accuracy 37.500 (37.500)
# valid_accuracy 38.660
