# %%
import argparse
import os
import torch
import random 
import numpy as np 
import torch.optim
import torch.nn as nn
import torch.utils.data
import torch.nn.functional as F
from torch.autograd import Variable
import torch.backends.cudnn as cudnn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt 
from itertools import cycle
import pickle
import sys

from resnetv2 import PreActResNet18 as ResNet18  
from utils import Labeled_dataset


parser = argparse.ArgumentParser(description='PyTorch Cifar10_100 Training')
parser.add_argument('--lr', default=0.1, type=float, help='initial learning rate')
parser.add_argument('--data_dir', help='The directory for data', default='trans_data', type=str)
parser.add_argument('--momentum', default=0.9, type=float, help='momentum')
parser.add_argument('--weight_decay', default=5e-4, type=float, help='weight decay')
parser.add_argument('--epochs', default=100, type=int, help='number of total epochs to run')
parser.add_argument('--print_freq', default=50, type=int, help='print frequency')
parser.add_argument('--decreasing_lr', default='60,80', help='decreasing strategy')
parser.add_argument('--save_dir', help='The directory used to save the trained models', default='cifar10_cil', type=str)
parser.add_argument('--gpu', type=int, default=0, help='gpu device id')
parser.add_argument('--seed', type=int, default=None, help='random seed')
parser.add_argument('--batch_size', default=128, type=int, help='batch size')
parser.add_argument('--load_model', default=False, type=eval, choices=[True, False], help='load last checkpoint to continue training')

best_prec1 = 0

# %%
def validate(val_loader, model, criterion, if_main=False):

    losses = AverageMeter()
    top1 = AverageMeter()

    # switch to evaluate mode
    model.eval()

    for i, (input, target) in enumerate(val_loader):
        input = input.cuda()
        target = target.long().cuda()

        # compute output
        with torch.no_grad():
            output = model(input, main_fc=if_main)
            loss = criterion(output, target)

        output = output.float()
        loss = loss.float()

        # measure accuracy and record loss
        prec1 = accuracy(output.data, target)[0]
        losses.update(loss.item(), input.size(0))
        top1.update(prec1.item(), input.size(0))

        if i % args.print_freq == 0:
            print('Test: [{0}/{1}]\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Accuracy {top1.val:.3f} ({top1.avg:.3f})'.format(
                      i, len(val_loader), loss=losses, top1=top1))

    print('valid_accuracy {top1.avg:.3f}'.format(top1=top1))

    return top1.avg

# %%
def train(rand_loader, new_balance_loader, old_balance_loader, model, criterion, optimizer, epoch):
    
    losses = AverageMeter()
    top1 = AverageMeter()

    coef_old = int(args.batch_size*4/5)/64
    coef_new = int(args.batch_size/5)/64

    # switch to train mode
    model.train()


    for i, (input, target) in enumerate(rand_loader):

        
        input = input.cuda()

        target = target.long().cuda()

        # random input
        output_gt = model(input, main_fc=False)
        loss_rand = criterion(output_gt, target)
        
        
        if tensor_allNaN(output_gt):
            print('output_gt')
            sys.exit()
        if tensor_allNaN(loss_rand):
            print('loss_rand')
            sys.exit()
            
        loss = loss_rand
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        output = output_gt.float()
        loss = loss.float()
        # measure accuracy and record loss
        prec1 = accuracy(output.data, target)[0]   
        losses.update(loss.item(), input.size(0))
        top1.update(prec1.item(), input.size(0))

        if i % args.print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Accuracy {top1.val:.3f} ({top1.avg:.3f})'.format(
                      epoch, i, len(rand_loader), loss=losses, top1=top1))
            

    print('train_accuracy {top1.avg:.3f}'.format(top1=top1))

    return top1.avg

# %%
def save_checkpoint(state, filename='weight.pt'):
    """
    Save the training model
    """
    torch.save(state, filename)

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
# output.shape = [batch size, num_class]

def accuracy(output, target, topk=(1,)):
    """Computes the precision@k for the specified values of k"""
    maxk = max(topk)
    batch_size = target.size(0)

    _, pred = output.topk(maxk, 1, True, True)
    pred = pred.t()
    correct = pred.eq(target.view(1, -1).expand_as(pred))

    res = []
    for k in topk:
        correct_k = correct[:k].view(-1).float().sum(0)
        
        res.append(correct_k.mul_(100.0 / batch_size))
    return res

# %%
def setup_seed(seed): 
    torch.manual_seed(seed) 
    torch.cuda.manual_seed_all(seed) 
    np.random.seed(seed) 
    random.seed(seed) 
    torch.backends.cudnn.deterministic = True

# %%
def tensor_allNaN(tensor):
    all_Nan = torch.isnan(tensor).all()
    if all_Nan:
        return True
    else:
        return False

# %% [markdown]
# # ==== below ================

# %% [markdown]
# ### prepare data

# %%
global args, best_prec1

# %%
# jupyter notebook input workaround
# args = parser.parse_args()
args = parser.parse_args(args=['--save_dir', 'output', 
                               '--data_dir', 'trans_data', 
                               '--gpu', '4', 
                               '--epochs', '200', 
                               '--load_model', 'False',
                               '--seed', '1'
                              ])

print(args)
# Out:
# Namespace(batch_size=128, data_dir='trans_data', decreasing_lr='60,80', epochs=200, gpu=4, load_model=False, lr=0.1, momentum=0.9, print_freq=50, save_dir='output', seed=1, weight_decay=0.0005)

# %%
path_head = args.data_dir
train_path = os.path.join(path_head,'4500_labeled_images_cifar10_train.pkl')
old_img_path = os.path.join(path_head,'100_labeled_images_cifar10_train.pkl')
val_path = os.path.join(path_head,'500_labeled_images_cifar10_val.pkl')
test_path = os.path.join(path_head,'labeled_images_cifar10_test.pkl')
sequence = np.random.permutation(10)
print('class sequence: ', sequence)

torch.cuda.set_device(int(args.gpu))

if args.seed:
    setup_seed(args.seed)

os.makedirs(args.save_dir, exist_ok=True)

train_trans = transforms.Compose([
        transforms.ToPILImage(),
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, 4),
        transforms.ToTensor()
    ])

val_trans = transforms.Compose([
        transforms.ToPILImage(),
        transforms.ToTensor()
    ])

criterion = nn.CrossEntropyLoss()
criterion = criterion.cuda()
decreasing_lr = list(map(int, args.decreasing_lr.split(',')))

model = ResNet18(num_classes=10)
model.cuda()

starting_epoch = 0

optimizer = torch.optim.SGD(model.parameters(), args.lr,
                            momentum=args.momentum,
                            weight_decay=args.weight_decay)

scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=decreasing_lr, gamma=0.1)


#prepare dataset
train_dataset = Labeled_dataset(train_path, train_trans, sequence[8:10], offset=8)
train_old_dataset = Labeled_dataset(old_img_path, train_trans, sequence[:8], offset=0)
val_dataset = Labeled_dataset(val_path, val_trans, sequence[:10], offset=0)

train_random_dataset = torch.utils.data.dataset.ConcatDataset((train_dataset,train_old_dataset))
# Out:
# class sequence:  [6 1 5 9 2 8 3 7 0 4]
# target list =  [0 4]
# target list =  [6 1 5 9 2 8 3 7]
# target list =  [6 1 5 9 2 8 3 7 0 4]

# %%
train_loader_random = torch.utils.data.DataLoader(
    train_random_dataset,
    batch_size=args.batch_size, shuffle=True,
    num_workers=2, pin_memory=True)

train_loader_balance_new = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=int(args.batch_size/5), shuffle=True,
    num_workers=2, pin_memory=True)

train_loader_balance_old = torch.utils.data.DataLoader(
    train_old_dataset,
    batch_size=int(args.batch_size*4/5), shuffle=True,
    num_workers=2, pin_memory=True)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=args.batch_size, shuffle=False,
    num_workers=2, pin_memory=True)

# %% [markdown]
# ### start to train

# %%
# if load a checkpoint or not
if args.load_model:
    checkpoint =  torch.load(os.path.join(args.save_dir, 'checkpoint_baseline.pt'))
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    scheduler.load_state_dict(checkpoint['scheduler'])
    starting_epoch = checkpoint['epoch']
    best_prec1 = checkpoint['best_prec1']
    print('starting_epoch: ', starting_epoch)
    print('best_prec1: ', best_prec1)



# index, acc
train_acc = [[],[]]
ta_imba = [[],[]]


for epoch in range(starting_epoch, starting_epoch + args.epochs):
    print('='*50)
    print("The learning rate is {}".format(optimizer.param_groups[0]['lr']))

    train_accuracy = train(train_loader_random, train_loader_balance_new, train_loader_balance_old, model, criterion, optimizer, epoch)
    
    prec1_imba = validate(val_loader, model, criterion, if_main=False)
    

    train_acc[0].append(epoch)
    ta_imba[0].append(epoch)
    
    train_acc[1].append(train_accuracy)
    ta_imba[1].append(prec1_imba)

    scheduler.step()

    # remember best prec@1 and save checkpoint (only imba)
    is_best = prec1_imba > best_prec1
    best_prec1 = max(prec1_imba, best_prec1)

    if is_best:
        save_checkpoint({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
        }, filename=os.path.join(args.save_dir, 'best_model_baseline.pt'))

    save_checkpoint({
        'epoch': epoch + 1,
        'state_dict': model.state_dict(),
        'best_prec1': best_prec1,
        'optimizer': optimizer.state_dict(),
        'scheduler': scheduler.state_dict(),
    }, filename=os.path.join(args.save_dir, 'checkpoint_baseline.pt'))

    plt.plot(train_acc[0], train_acc[1], label='train_acc')
    plt.plot(ta_imba[0], ta_imba[1], label='TA_imba')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(args.save_dir, 'net_train_baseline.png'))
    plt.close()
# Out:
# ==================================================
# The learning rate is 0.1
# Epoch: [0][0/77]	Loss 2.1710 (2.1710)	Accuracy 21.875 (21.875)
# Epoch: [0][50/77]	Loss 35.6484 (14.2968)	Accuracy 44.531 (45.634)
# train_accuracy 46.082
# Test: [0/40]	Loss 8.0866 (8.0866)	Accuracy 0.000 (0.000)
# valid_accuracy 10.000
# ==================================================
# The learning rate is 0.1
# Epoch: [1][0/77]	Loss 1.0388 (1.0388)	Accuracy 48.438 (48.438)
# Epoch: [1][50/77]	Loss 1.7030 (1.2440)	Accuracy 44.531 (46.783)
# train_accuracy 46.735
# Test: [0/40]	Loss 4.5020 (4.5020)	Accuracy 0.000 (0.000)
# valid_accuracy 10.440
# ==================================================
# The learning rate is 0.1
# Epoch: [2][0/77]	Loss 1.2117 (1.2117)	Accuracy 51.562 (51.562)
# Epoch: [2][50/77]	Loss 0.9516 (1.0852)	Accuracy 53.125 (50.766)
# train_accuracy 50.622
# Test: [0/40]	Loss 4.5467 (4.5467)	Accuracy 0.000 (0.000)
# valid_accuracy 10.600
# ==================================================
# The learning rate is 0.1
# Epoch: [3][0/77]	Loss 1.0880 (1.0880)	Accuracy 53.906 (53.906)
# Epoch: [3][50/77]	Loss 1.0532 (1.0773)	Accuracy 47.656 (53.048)
# train_accuracy 53.143
# Test: [0/40]	Loss 4.5400 (4.5400)	Accuracy 0.000 (0.000)
# valid_accuracy 10.560
# ==================================================
# The learning rate is 0.1
# Epoch: [4][0/77]	Loss 1.1116 (1.1116)	Accuracy 45.312 (45.312)
# Epoch: [4][50/77]	Loss 1.0087 (1.0707)	Accuracy 47.656 (53.140)
# train_accuracy 52.673
# Test: [0/40]	Loss 5.8030 (5.8030)	Accuracy 0.000 (0.000)
# valid_accuracy 10.880
# ==================================================
# The learning rate is 0.1
# Epoch: [5][0/77]	Loss 1.1744 (1.1744)	Accuracy 56.250 (56.250)
# Epoch: [5][50/77]	Loss 1.1192 (1.1311)	Accuracy 50.781 (53.600)
# train_accuracy 53.878
# Test: [0/40]	Loss 4.6730 (4.6730)	Accuracy 0.000 (0.000)
# valid_accuracy 10.820
# ==================================================
# The learning rate is 0.1
# Epoch: [6][0/77]	Loss 1.1194 (1.1194)	Accuracy 58.594 (58.594)
# Epoch: [6][50/77]	Loss 1.0621 (1.2226)	Accuracy 53.125 (46.875)
# train_accuracy 46.969
# Test: [0/40]	Loss 4.5321 (4.5321)	Accuracy 0.000 (0.000)
# valid_accuracy 9.980
# ==================================================
# The learning rate is 0.1
# Epoch: [7][0/77]	Loss 1.0097 (1.0097)	Accuracy 51.562 (51.562)
# Epoch: [7][50/77]	Loss 1.0133 (1.1184)	Accuracy 40.625 (44.975)
# train_accuracy 45.306
# Test: [0/40]	Loss 4.5625 (4.5625)	Accuracy 0.000 (0.000)
# valid_accuracy 9.980
# ==================================================
# The learning rate is 0.1
# Epoch: [8][0/77]	Loss 1.1957 (1.1957)	Accuracy 38.281 (38.281)
# Epoch: [8][50/77]	Loss 1.0642 (1.1119)	Accuracy 53.906 (45.435)
# train_accuracy 45.582
# Test: [0/40]	Loss 4.5679 (4.5679)	Accuracy 0.000 (0.000)
# valid_accuracy 10.000
# ==================================================
# The learning rate is 0.1
# Epoch: [9][0/77]	Loss 1.0526 (1.0526)	Accuracy 42.188 (42.188)
# Epoch: [9][50/77]	Loss 1.2486 (1.0870)	Accuracy 36.719 (45.741)
# train_accuracy 45.908
# Test: [0/40]	Loss 4.5488 (4.5488)	Accuracy 0.000 (0.000)
# valid_accuracy 10.060
# ==================================================
# The learning rate is 0.1
# Epoch: [10][0/77]	Loss 0.9837 (0.9837)	Accuracy 50.781 (50.781)
# Epoch: [10][50/77]	Loss 1.0880 (1.0943)	Accuracy 46.875 (45.772)
# train_accuracy 46.122
# Test: [0/40]	Loss 4.5859 (4.5859)	Accuracy 0.000 (0.000)
# valid_accuracy 10.100
# ==================================================
# The learning rate is 0.1
# Epoch: [11][0/77]	Loss 0.9813 (0.9813)	Accuracy 51.562 (51.562)
# Epoch: [11][50/77]	Loss 1.0790 (1.1153)	Accuracy 47.656 (46.109)
# train_accuracy 46.112
# Test: [0/40]	Loss 4.5699 (4.5699)	Accuracy 0.000 (0.000)
# valid_accuracy 10.000
# ==================================================
# The learning rate is 0.1
# Epoch: [12][0/77]	Loss 1.1116 (1.1116)	Accuracy 50.781 (50.781)
# Epoch: [12][50/77]	Loss 1.2249 (1.0974)	Accuracy 45.312 (46.706)
# train_accuracy 46.194
# Test: [0/40]	Loss 4.5220 (4.5220)	Accuracy 0.000 (0.000)
# valid_accuracy 10.100
# ==================================================
# The learning rate is 0.1
# Epoch: [13][0/77]	Loss 1.1072 (1.1072)	Accuracy 44.531 (44.531)
# Epoch: [13][50/77]	Loss 1.0577 (1.1062)	Accuracy 51.562 (45.711)
# train_accuracy 45.878
# Test: [0/40]	Loss 4.6489 (4.6489)	Accuracy 0.000 (0.000)
# valid_accuracy 10.060
# ==================================================
# The learning rate is 0.1
# Epoch: [14][0/77]	Loss 1.2822 (1.2822)	Accuracy 35.156 (35.156)
# Epoch: [14][50/77]	Loss 0.9867 (1.0933)	Accuracy 47.656 (45.772)
# train_accuracy 45.786
# Test: [0/40]	Loss 4.5228 (4.5228)	Accuracy 0.000 (0.000)
# valid_accuracy 10.140
# ==================================================
# The learning rate is 0.1
# Epoch: [15][0/77]	Loss 1.0563 (1.0563)	Accuracy 40.625 (40.625)
# Epoch: [15][50/77]	Loss 1.1329 (1.0756)	Accuracy 42.969 (45.711)
# train_accuracy 45.959
# Test: [0/40]	Loss 4.5221 (4.5221)	Accuracy 0.000 (0.000)
# valid_accuracy 10.120
# ==================================================
# The learning rate is 0.1
# Epoch: [16][0/77]	Loss 1.1017 (1.1017)	Accuracy 49.219 (49.219)
# Epoch: [16][50/77]	Loss 0.9338 (1.0907)	Accuracy 46.875 (45.987)
# train_accuracy 45.653
# Test: [0/40]	Loss 4.5525 (4.5525)	Accuracy 0.000 (0.000)
# valid_accuracy 10.020
# ==================================================
# The learning rate is 0.1
# Epoch: [17][0/77]	Loss 1.1247 (1.1247)	Accuracy 46.875 (46.875)
# Epoch: [17][50/77]	Loss 0.9573 (1.0765)	Accuracy 50.000 (46.140)
# train_accuracy 45.806
# Test: [0/40]	Loss 4.5500 (4.5500)	Accuracy 0.000 (0.000)
# valid_accuracy 10.180
# ==================================================
# The learning rate is 0.1
# Epoch: [18][0/77]	Loss 0.9589 (0.9589)	Accuracy 42.188 (42.188)
# Epoch: [18][50/77]	Loss 1.0176 (1.0895)	Accuracy 49.219 (45.910)
# train_accuracy 45.867
# Test: [0/40]	Loss 4.5705 (4.5705)	Accuracy 0.000 (0.000)
# valid_accuracy 9.940
# ==================================================
# The learning rate is 0.1
# Epoch: [19][0/77]	Loss 1.1041 (1.1041)	Accuracy 43.750 (43.750)
# Epoch: [19][50/77]	Loss 0.9189 (1.0906)	Accuracy 45.312 (46.278)
# train_accuracy 46.745
# Test: [0/40]	Loss 4.5742 (4.5742)	Accuracy 0.000 (0.000)
# valid_accuracy 10.420
# ==================================================
# The learning rate is 0.1
# Epoch: [20][0/77]	Loss 1.1536 (1.1536)	Accuracy 49.219 (49.219)
# Epoch: [20][50/77]	Loss 1.2420 (1.0740)	Accuracy 48.438 (50.781)
# train_accuracy 51.888
# Test: [0/40]	Loss 4.5597 (4.5597)	Accuracy 0.000 (0.000)
# valid_accuracy 10.640
# ==================================================
# The learning rate is 0.1
# Epoch: [21][0/77]	Loss 0.9410 (0.9410)	Accuracy 63.281 (63.281)
# Epoch: [21][50/77]	Loss 1.1496 (1.0685)	Accuracy 45.312 (54.596)
# train_accuracy 54.929
# Test: [0/40]	Loss 4.5757 (4.5757)	Accuracy 0.000 (0.000)
# valid_accuracy 10.740
# ==================================================
# The learning rate is 0.1
# Epoch: [22][0/77]	Loss 1.0066 (1.0066)	Accuracy 57.031 (57.031)
# Epoch: [22][50/77]	Loss 0.7316 (1.0326)	Accuracy 71.875 (60.401)
# train_accuracy 65.092
# Test: [0/40]	Loss 4.3683 (4.3683)	Accuracy 0.000 (0.000)
# valid_accuracy 16.200
# ==================================================
# The learning rate is 0.1
# Epoch: [23][0/77]	Loss 0.7443 (0.7443)	Accuracy 75.781 (75.781)
# Epoch: [23][50/77]	Loss 0.6747 (0.8937)	Accuracy 75.781 (72.886)
# train_accuracy 73.796
# Test: [0/40]	Loss 4.1215 (4.1215)	Accuracy 0.000 (0.000)
# valid_accuracy 16.360
# ==================================================
# The learning rate is 0.1
# Epoch: [24][0/77]	Loss 0.8258 (0.8258)	Accuracy 77.344 (77.344)
# Epoch: [24][50/77]	Loss 0.8985 (0.8373)	Accuracy 72.656 (75.383)
# train_accuracy 75.112
# Test: [0/40]	Loss 4.4770 (4.4770)	Accuracy 0.000 (0.000)
# valid_accuracy 16.480
# ==================================================
# The learning rate is 0.1
# Epoch: [25][0/77]	Loss 0.7641 (0.7641)	Accuracy 78.125 (78.125)
# Epoch: [25][50/77]	Loss 1.0088 (0.8372)	Accuracy 74.219 (75.368)
# train_accuracy 75.643
# Test: [0/40]	Loss 4.0930 (4.0930)	Accuracy 0.000 (0.000)
# valid_accuracy 16.660
# ==================================================
# The learning rate is 0.1
# Epoch: [26][0/77]	Loss 0.7421 (0.7421)	Accuracy 77.344 (77.344)
# Epoch: [26][50/77]	Loss 0.9165 (0.7946)	Accuracy 72.656 (76.103)
# train_accuracy 76.388
# Test: [0/40]	Loss 4.0064 (4.0064)	Accuracy 0.000 (0.000)
# valid_accuracy 16.640
# ==================================================
# The learning rate is 0.1
# Epoch: [27][0/77]	Loss 0.7916 (0.7916)	Accuracy 78.906 (78.906)
# Epoch: [27][50/77]	Loss 0.9070 (0.8087)	Accuracy 75.781 (76.317)
# train_accuracy 76.867
# Test: [0/40]	Loss 4.1054 (4.1054)	Accuracy 0.000 (0.000)
# valid_accuracy 14.260
# ==================================================
# The learning rate is 0.1
# Epoch: [28][0/77]	Loss 0.9502 (0.9502)	Accuracy 71.875 (71.875)
# Epoch: [28][50/77]	Loss 0.8176 (0.7736)	Accuracy 76.562 (77.359)
# train_accuracy 77.663
# Test: [0/40]	Loss 4.3422 (4.3422)	Accuracy 0.000 (0.000)
# valid_accuracy 15.280
# ==================================================
# The learning rate is 0.1
# Epoch: [29][0/77]	Loss 0.8549 (0.8549)	Accuracy 80.469 (80.469)
# Epoch: [29][50/77]	Loss 0.8130 (0.7509)	Accuracy 75.000 (78.263)
# train_accuracy 78.102
# Test: [0/40]	Loss 3.7022 (3.7022)	Accuracy 0.000 (0.000)
# valid_accuracy 17.080
# ==================================================
# The learning rate is 0.1
# Epoch: [30][0/77]	Loss 0.7640 (0.7640)	Accuracy 78.125 (78.125)
# Epoch: [30][50/77]	Loss 0.8328 (0.7589)	Accuracy 77.344 (77.574)
# train_accuracy 78.224
# Test: [0/40]	Loss 4.2283 (4.2283)	Accuracy 0.000 (0.000)
# valid_accuracy 16.600
# ==================================================
# The learning rate is 0.1
# Epoch: [31][0/77]	Loss 0.6967 (0.6967)	Accuracy 78.906 (78.906)
# Epoch: [31][50/77]	Loss 0.7725 (0.7386)	Accuracy 75.781 (79.044)
# train_accuracy 78.959
# Test: [0/40]	Loss 4.0460 (4.0460)	Accuracy 0.000 (0.000)
# valid_accuracy 15.600
# ==================================================
# The learning rate is 0.1
# Epoch: [32][0/77]	Loss 0.7885 (0.7885)	Accuracy 78.125 (78.125)
# Epoch: [32][50/77]	Loss 0.7899 (0.7191)	Accuracy 79.688 (79.075)
# train_accuracy 78.908
# Test: [0/40]	Loss 4.2241 (4.2241)	Accuracy 0.000 (0.000)
# valid_accuracy 17.140
# ==================================================
# The learning rate is 0.1
# Epoch: [33][0/77]	Loss 0.8053 (0.8053)	Accuracy 76.562 (76.562)
# Epoch: [33][50/77]	Loss 0.7999 (0.7461)	Accuracy 77.344 (78.646)
# train_accuracy 79.163
# Test: [0/40]	Loss 4.1184 (4.1184)	Accuracy 0.000 (0.000)
# valid_accuracy 16.660
# ==================================================
# The learning rate is 0.1
# Epoch: [34][0/77]	Loss 0.7334 (0.7334)	Accuracy 79.688 (79.688)
# Epoch: [34][50/77]	Loss 0.6930 (0.7288)	Accuracy 79.688 (79.305)
# train_accuracy 79.643
# Test: [0/40]	Loss 4.0990 (4.0990)	Accuracy 0.000 (0.000)
# valid_accuracy 16.820
# ==================================================
# The learning rate is 0.1
# Epoch: [35][0/77]	Loss 0.7912 (0.7912)	Accuracy 75.781 (75.781)
# Epoch: [35][50/77]	Loss 0.6094 (0.7039)	Accuracy 83.594 (79.396)
# train_accuracy 79.490
# Test: [0/40]	Loss 3.7459 (3.7459)	Accuracy 0.000 (0.000)
# valid_accuracy 17.260
# ==================================================
# The learning rate is 0.1
# Epoch: [36][0/77]	Loss 0.7017 (0.7017)	Accuracy 80.469 (80.469)
# Epoch: [36][50/77]	Loss 0.7094 (0.7018)	Accuracy 81.250 (79.442)
# train_accuracy 79.439
# Test: [0/40]	Loss 4.4964 (4.4964)	Accuracy 0.000 (0.000)
# valid_accuracy 16.580
# ==================================================
# The learning rate is 0.1
# Epoch: [37][0/77]	Loss 0.8250 (0.8250)	Accuracy 77.344 (77.344)
# Epoch: [37][50/77]	Loss 0.6787 (0.7058)	Accuracy 82.812 (79.871)
# train_accuracy 79.918
# Test: [0/40]	Loss 4.3371 (4.3371)	Accuracy 0.000 (0.000)
# valid_accuracy 14.780
# ==================================================
# The learning rate is 0.1
# Epoch: [38][0/77]	Loss 0.7440 (0.7440)	Accuracy 76.562 (76.562)
# Epoch: [38][50/77]	Loss 0.8419 (0.7194)	Accuracy 75.000 (79.259)
# train_accuracy 79.918
# Test: [0/40]	Loss 4.1525 (4.1525)	Accuracy 0.000 (0.000)
# valid_accuracy 17.160
# ==================================================
# The learning rate is 0.1
# Epoch: [39][0/77]	Loss 0.8418 (0.8418)	Accuracy 80.469 (80.469)
# Epoch: [39][50/77]	Loss 0.5918 (0.6981)	Accuracy 79.688 (80.224)
# train_accuracy 80.276
# Test: [0/40]	Loss 4.1710 (4.1710)	Accuracy 0.000 (0.000)
# valid_accuracy 17.260
# ==================================================
# The learning rate is 0.1
# Epoch: [40][0/77]	Loss 0.7147 (0.7147)	Accuracy 81.250 (81.250)
# Epoch: [40][50/77]	Loss 0.6086 (0.7000)	Accuracy 85.938 (80.147)
# train_accuracy 80.112
# Test: [0/40]	Loss 4.3883 (4.3883)	Accuracy 0.000 (0.000)
# valid_accuracy 16.680
# ==================================================
# The learning rate is 0.1
# Epoch: [41][0/77]	Loss 0.7591 (0.7591)	Accuracy 78.125 (78.125)
# Epoch: [41][50/77]	Loss 0.6357 (0.6778)	Accuracy 82.031 (81.081)
# train_accuracy 80.796
# Test: [0/40]	Loss 3.7534 (3.7534)	Accuracy 0.000 (0.000)
# valid_accuracy 17.380
# ==================================================
# The learning rate is 0.1
# Epoch: [42][0/77]	Loss 0.8569 (0.8569)	Accuracy 76.562 (76.562)
# Epoch: [42][50/77]	Loss 0.7061 (0.6792)	Accuracy 80.469 (80.959)
# train_accuracy 81.000
# Test: [0/40]	Loss 3.9673 (3.9673)	Accuracy 0.000 (0.000)
# valid_accuracy 17.460
# ==================================================
# The learning rate is 0.1
# Epoch: [43][0/77]	Loss 0.5665 (0.5665)	Accuracy 85.156 (85.156)
# Epoch: [43][50/77]	Loss 0.9196 (0.6748)	Accuracy 73.438 (81.311)
# train_accuracy 81.184
# Test: [0/40]	Loss 4.4015 (4.4015)	Accuracy 0.000 (0.000)
# valid_accuracy 17.400
# ==================================================
# The learning rate is 0.1
# Epoch: [44][0/77]	Loss 0.5811 (0.5811)	Accuracy 85.156 (85.156)
# Epoch: [44][50/77]	Loss 0.5915 (0.6786)	Accuracy 82.031 (81.173)
# train_accuracy 80.908
# Test: [0/40]	Loss 4.1205 (4.1205)	Accuracy 0.000 (0.000)
# valid_accuracy 17.340
# ==================================================
# The learning rate is 0.1
# Epoch: [45][0/77]	Loss 0.6233 (0.6233)	Accuracy 84.375 (84.375)
# Epoch: [45][50/77]	Loss 0.5373 (0.6706)	Accuracy 89.062 (81.801)
# train_accuracy 82.296
# Test: [0/40]	Loss 4.2912 (4.2912)	Accuracy 0.000 (0.000)
# valid_accuracy 17.720
# ==================================================
# The learning rate is 0.1
# Epoch: [46][0/77]	Loss 0.6437 (0.6437)	Accuracy 85.938 (85.938)
# Epoch: [46][50/77]	Loss 0.7217 (0.6439)	Accuracy 81.250 (82.629)
# train_accuracy 82.755
# Test: [0/40]	Loss 4.2881 (4.2881)	Accuracy 0.000 (0.000)
# valid_accuracy 17.840
# ==================================================
# The learning rate is 0.1
# Epoch: [47][0/77]	Loss 0.5469 (0.5469)	Accuracy 85.938 (85.938)
# Epoch: [47][50/77]	Loss 0.7602 (0.6367)	Accuracy 82.031 (83.211)
# train_accuracy 83.020
# Test: [0/40]	Loss 4.5347 (4.5347)	Accuracy 0.000 (0.000)
# valid_accuracy 17.520
# ==================================================
# The learning rate is 0.1
# Epoch: [48][0/77]	Loss 0.7436 (0.7436)	Accuracy 81.250 (81.250)
# Epoch: [48][50/77]	Loss 0.4500 (0.6161)	Accuracy 88.281 (83.869)
# train_accuracy 83.704
# Test: [0/40]	Loss 4.1085 (4.1085)	Accuracy 0.000 (0.000)
# valid_accuracy 17.700
# ==================================================
# The learning rate is 0.1
# Epoch: [49][0/77]	Loss 0.5537 (0.5537)	Accuracy 84.375 (84.375)
# Epoch: [49][50/77]	Loss 0.6726 (0.6194)	Accuracy 83.594 (83.578)
# train_accuracy 83.490
# Test: [0/40]	Loss 4.6937 (4.6937)	Accuracy 0.000 (0.000)
# valid_accuracy 17.960
# ==================================================
# The learning rate is 0.1
# Epoch: [50][0/77]	Loss 0.6703 (0.6703)	Accuracy 81.250 (81.250)
# Epoch: [50][50/77]	Loss 0.5520 (0.6216)	Accuracy 85.156 (83.456)
# train_accuracy 83.714
# Test: [0/40]	Loss 4.6953 (4.6953)	Accuracy 0.000 (0.000)
# valid_accuracy 17.900
# ==================================================
# The learning rate is 0.1
# Epoch: [51][0/77]	Loss 0.5239 (0.5239)	Accuracy 85.156 (85.156)
# Epoch: [51][50/77]	Loss 0.5285 (0.6043)	Accuracy 87.500 (83.762)
# train_accuracy 84.031
# Test: [0/40]	Loss 4.5675 (4.5675)	Accuracy 0.000 (0.000)
# valid_accuracy 17.180
# ==================================================
# The learning rate is 0.1
# Epoch: [52][0/77]	Loss 0.5103 (0.5103)	Accuracy 85.938 (85.938)
# Epoch: [52][50/77]	Loss 0.3788 (0.5840)	Accuracy 88.281 (84.406)
# train_accuracy 84.306
# Test: [0/40]	Loss 4.2548 (4.2548)	Accuracy 0.000 (0.000)
# valid_accuracy 18.200
# ==================================================
# The learning rate is 0.1
# Epoch: [53][0/77]	Loss 0.8058 (0.8058)	Accuracy 78.125 (78.125)
# Epoch: [53][50/77]	Loss 0.6393 (0.5916)	Accuracy 83.594 (83.900)
# train_accuracy 84.071
# Test: [0/40]	Loss 3.6653 (3.6653)	Accuracy 0.000 (0.000)
# valid_accuracy 18.000
# ==================================================
# The learning rate is 0.1
# Epoch: [54][0/77]	Loss 0.6767 (0.6767)	Accuracy 78.906 (78.906)
# Epoch: [54][50/77]	Loss 0.6643 (0.5769)	Accuracy 81.250 (84.298)
# train_accuracy 84.571
# Test: [0/40]	Loss 4.2744 (4.2744)	Accuracy 0.000 (0.000)
# valid_accuracy 17.880
# ==================================================
# The learning rate is 0.1
# Epoch: [55][0/77]	Loss 0.5252 (0.5252)	Accuracy 85.938 (85.938)
# Epoch: [55][50/77]	Loss 0.5662 (0.5973)	Accuracy 84.375 (83.379)
# train_accuracy 84.102
# Test: [0/40]	Loss 4.2341 (4.2341)	Accuracy 0.000 (0.000)
# valid_accuracy 18.820
# ==================================================
# The learning rate is 0.1
# Epoch: [56][0/77]	Loss 0.4383 (0.4383)	Accuracy 88.281 (88.281)
# Epoch: [56][50/77]	Loss 0.6629 (0.5642)	Accuracy 84.375 (84.115)
# train_accuracy 84.429
# Test: [0/40]	Loss 4.6664 (4.6664)	Accuracy 0.000 (0.000)
# valid_accuracy 18.140
# ==================================================
# The learning rate is 0.1
# Epoch: [57][0/77]	Loss 0.5998 (0.5998)	Accuracy 84.375 (84.375)
# Epoch: [57][50/77]	Loss 0.9057 (0.5585)	Accuracy 78.906 (84.758)
# train_accuracy 84.673
# Test: [0/40]	Loss 4.1189 (4.1189)	Accuracy 0.000 (0.000)
# valid_accuracy 17.860
# ==================================================
# The learning rate is 0.1
# Epoch: [58][0/77]	Loss 0.4281 (0.4281)	Accuracy 89.062 (89.062)
# Epoch: [58][50/77]	Loss 0.4361 (0.5489)	Accuracy 89.062 (84.850)
# train_accuracy 85.000
# Test: [0/40]	Loss 4.1591 (4.1591)	Accuracy 0.000 (0.000)
# valid_accuracy 18.200
# ==================================================
# The learning rate is 0.1
# Epoch: [59][0/77]	Loss 0.4028 (0.4028)	Accuracy 90.625 (90.625)
# Epoch: [59][50/77]	Loss 0.5932 (0.5617)	Accuracy 85.938 (84.436)
# train_accuracy 84.857
# Test: [0/40]	Loss 3.0809 (3.0809)	Accuracy 0.000 (0.000)
# valid_accuracy 18.880
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [60][0/77]	Loss 0.4011 (0.4011)	Accuracy 88.281 (88.281)
# Epoch: [60][50/77]	Loss 0.4173 (0.5008)	Accuracy 87.500 (86.305)
# train_accuracy 86.122
# Test: [0/40]	Loss 3.8121 (3.8121)	Accuracy 0.000 (0.000)
# valid_accuracy 20.220
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [61][0/77]	Loss 0.6082 (0.6082)	Accuracy 82.031 (82.031)
# Epoch: [61][50/77]	Loss 0.5932 (0.4980)	Accuracy 82.812 (86.673)
# train_accuracy 86.888
# Test: [0/40]	Loss 3.9499 (3.9499)	Accuracy 0.000 (0.000)
# valid_accuracy 20.460
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [62][0/77]	Loss 0.3223 (0.3223)	Accuracy 92.969 (92.969)
# Epoch: [62][50/77]	Loss 0.5049 (0.4719)	Accuracy 85.938 (87.163)
# train_accuracy 86.888
# Test: [0/40]	Loss 3.8460 (3.8460)	Accuracy 0.000 (0.000)
# valid_accuracy 20.420
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [63][0/77]	Loss 0.3809 (0.3809)	Accuracy 90.625 (90.625)
# Epoch: [63][50/77]	Loss 0.4077 (0.4753)	Accuracy 88.281 (87.071)
# train_accuracy 86.969
# Test: [0/40]	Loss 3.8221 (3.8221)	Accuracy 0.000 (0.000)
# valid_accuracy 21.660
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [64][0/77]	Loss 0.3715 (0.3715)	Accuracy 90.625 (90.625)
# Epoch: [64][50/77]	Loss 0.5530 (0.4694)	Accuracy 84.375 (87.240)
# train_accuracy 87.163
# Test: [0/40]	Loss 3.8588 (3.8588)	Accuracy 0.000 (0.000)
# valid_accuracy 20.520
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [65][0/77]	Loss 0.3998 (0.3998)	Accuracy 89.062 (89.062)
# Epoch: [65][50/77]	Loss 0.5865 (0.4782)	Accuracy 81.250 (86.857)
# train_accuracy 87.133
# Test: [0/40]	Loss 3.8548 (3.8548)	Accuracy 0.000 (0.000)
# valid_accuracy 20.620
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [66][0/77]	Loss 0.6569 (0.6569)	Accuracy 82.812 (82.812)
# Epoch: [66][50/77]	Loss 0.6366 (0.4826)	Accuracy 84.375 (86.949)
# train_accuracy 87.245
# Test: [0/40]	Loss 3.9225 (3.9225)	Accuracy 0.000 (0.000)
# valid_accuracy 21.540
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [67][0/77]	Loss 0.3683 (0.3683)	Accuracy 89.062 (89.062)
# Epoch: [67][50/77]	Loss 0.5714 (0.4676)	Accuracy 84.375 (87.561)
# train_accuracy 87.276
# Test: [0/40]	Loss 3.9130 (3.9130)	Accuracy 0.000 (0.000)
# valid_accuracy 22.120
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [68][0/77]	Loss 0.4840 (0.4840)	Accuracy 88.281 (88.281)
# Epoch: [68][50/77]	Loss 0.5636 (0.4520)	Accuracy 84.375 (87.837)
# train_accuracy 87.398
# Test: [0/40]	Loss 3.7198 (3.7198)	Accuracy 0.000 (0.000)
# valid_accuracy 22.320
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [69][0/77]	Loss 0.3370 (0.3370)	Accuracy 90.625 (90.625)
# Epoch: [69][50/77]	Loss 0.4663 (0.4643)	Accuracy 87.500 (87.439)
# train_accuracy 87.500
# Test: [0/40]	Loss 3.8926 (3.8926)	Accuracy 0.000 (0.000)
# valid_accuracy 21.600
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [70][0/77]	Loss 0.5215 (0.5215)	Accuracy 86.719 (86.719)
# Epoch: [70][50/77]	Loss 0.3741 (0.4630)	Accuracy 87.500 (87.423)
# train_accuracy 87.622
# Test: [0/40]	Loss 3.9154 (3.9154)	Accuracy 0.000 (0.000)
# valid_accuracy 22.180
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [71][0/77]	Loss 0.3800 (0.3800)	Accuracy 89.844 (89.844)
# Epoch: [71][50/77]	Loss 0.5831 (0.4552)	Accuracy 84.375 (87.454)
# train_accuracy 87.408
# Test: [0/40]	Loss 3.6453 (3.6453)	Accuracy 0.000 (0.000)
# valid_accuracy 22.560
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [72][0/77]	Loss 0.3593 (0.3593)	Accuracy 92.188 (92.188)
# Epoch: [72][50/77]	Loss 0.3338 (0.4596)	Accuracy 87.500 (87.331)
# train_accuracy 87.531
# Test: [0/40]	Loss 4.0946 (4.0946)	Accuracy 0.000 (0.000)
# valid_accuracy 22.240
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [73][0/77]	Loss 0.4285 (0.4285)	Accuracy 89.062 (89.062)
# Epoch: [73][50/77]	Loss 0.4979 (0.4458)	Accuracy 86.719 (87.638)
# train_accuracy 87.694
# Test: [0/40]	Loss 3.6911 (3.6911)	Accuracy 0.000 (0.000)
# valid_accuracy 22.700
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [74][0/77]	Loss 0.4540 (0.4540)	Accuracy 87.500 (87.500)
# Epoch: [74][50/77]	Loss 0.4793 (0.4494)	Accuracy 86.719 (87.791)
# train_accuracy 87.561
# Test: [0/40]	Loss 3.8271 (3.8271)	Accuracy 0.000 (0.000)
# valid_accuracy 22.840
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [75][0/77]	Loss 0.3806 (0.3806)	Accuracy 90.625 (90.625)
# Epoch: [75][50/77]	Loss 0.4561 (0.4415)	Accuracy 86.719 (87.944)
# train_accuracy 87.755
# Test: [0/40]	Loss 4.2866 (4.2866)	Accuracy 0.000 (0.000)
# valid_accuracy 20.620
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [76][0/77]	Loss 0.4340 (0.4340)	Accuracy 87.500 (87.500)
# Epoch: [76][50/77]	Loss 0.5373 (0.4664)	Accuracy 85.156 (87.684)
# train_accuracy 88.010
# Test: [0/40]	Loss 3.9986 (3.9986)	Accuracy 0.000 (0.000)
# valid_accuracy 23.680
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [77][0/77]	Loss 0.6211 (0.6211)	Accuracy 85.156 (85.156)
# Epoch: [77][50/77]	Loss 0.4741 (0.4436)	Accuracy 88.281 (87.868)
# train_accuracy 87.990
# Test: [0/40]	Loss 4.1552 (4.1552)	Accuracy 0.000 (0.000)
# valid_accuracy 23.740
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [78][0/77]	Loss 0.3566 (0.3566)	Accuracy 89.844 (89.844)
# Epoch: [78][50/77]	Loss 0.5430 (0.4517)	Accuracy 84.375 (87.653)
# train_accuracy 87.908
# Test: [0/40]	Loss 3.8939 (3.8939)	Accuracy 0.000 (0.000)
# valid_accuracy 23.440
# ==================================================
# The learning rate is 0.010000000000000002
# Epoch: [79][0/77]	Loss 0.4956 (0.4956)	Accuracy 84.375 (84.375)
# Epoch: [79][50/77]	Loss 0.3923 (0.4391)	Accuracy 89.844 (88.097)
# train_accuracy 88.061
# Test: [0/40]	Loss 4.1361 (4.1361)	Accuracy 0.000 (0.000)
# valid_accuracy 23.100
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [80][0/77]	Loss 0.4751 (0.4751)	Accuracy 85.938 (85.938)
# Epoch: [80][50/77]	Loss 0.4323 (0.4250)	Accuracy 87.500 (88.266)
# train_accuracy 88.469
# Test: [0/40]	Loss 3.8966 (3.8966)	Accuracy 0.000 (0.000)
# valid_accuracy 23.980
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [81][0/77]	Loss 0.5423 (0.5423)	Accuracy 86.719 (86.719)
# Epoch: [81][50/77]	Loss 0.3597 (0.4249)	Accuracy 91.406 (88.297)
# train_accuracy 88.480
# Test: [0/40]	Loss 3.8646 (3.8646)	Accuracy 0.000 (0.000)
# valid_accuracy 23.920
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [82][0/77]	Loss 0.4428 (0.4428)	Accuracy 88.281 (88.281)
# Epoch: [82][50/77]	Loss 0.3365 (0.4071)	Accuracy 90.625 (88.511)
# train_accuracy 88.306
# Test: [0/40]	Loss 3.8397 (3.8397)	Accuracy 0.000 (0.000)
# valid_accuracy 23.620
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [83][0/77]	Loss 0.3316 (0.3316)	Accuracy 90.625 (90.625)
# Epoch: [83][50/77]	Loss 0.3957 (0.4128)	Accuracy 89.062 (88.894)
# train_accuracy 88.867
# Test: [0/40]	Loss 3.9276 (3.9276)	Accuracy 0.000 (0.000)
# valid_accuracy 24.000
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [84][0/77]	Loss 0.4376 (0.4376)	Accuracy 89.062 (89.062)
# Epoch: [84][50/77]	Loss 0.4222 (0.4110)	Accuracy 86.719 (88.465)
# train_accuracy 88.592
# Test: [0/40]	Loss 3.9149 (3.9149)	Accuracy 0.000 (0.000)
# valid_accuracy 24.080
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [85][0/77]	Loss 0.5376 (0.5376)	Accuracy 82.031 (82.031)
# Epoch: [85][50/77]	Loss 0.3199 (0.4101)	Accuracy 90.625 (88.725)
# train_accuracy 88.827
# Test: [0/40]	Loss 3.9696 (3.9696)	Accuracy 0.000 (0.000)
# valid_accuracy 23.920
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [86][0/77]	Loss 0.4442 (0.4442)	Accuracy 88.281 (88.281)
# Epoch: [86][50/77]	Loss 0.3143 (0.4110)	Accuracy 92.969 (89.093)
# train_accuracy 88.847
# Test: [0/40]	Loss 3.9005 (3.9005)	Accuracy 0.000 (0.000)
# valid_accuracy 24.220
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [87][0/77]	Loss 0.4569 (0.4569)	Accuracy 89.062 (89.062)
# Epoch: [87][50/77]	Loss 0.3230 (0.4236)	Accuracy 90.625 (88.266)
# train_accuracy 88.561
# Test: [0/40]	Loss 3.9406 (3.9406)	Accuracy 0.000 (0.000)
# valid_accuracy 24.200
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [88][0/77]	Loss 0.4394 (0.4394)	Accuracy 88.281 (88.281)
# Epoch: [88][50/77]	Loss 0.3730 (0.4088)	Accuracy 90.625 (88.848)
# train_accuracy 88.908
# Test: [0/40]	Loss 3.9525 (3.9525)	Accuracy 0.000 (0.000)
# valid_accuracy 24.220
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [89][0/77]	Loss 0.3683 (0.3683)	Accuracy 88.281 (88.281)
# Epoch: [89][50/77]	Loss 0.3934 (0.4079)	Accuracy 90.625 (88.894)
# train_accuracy 88.867
# Test: [0/40]	Loss 3.9763 (3.9763)	Accuracy 0.000 (0.000)
# valid_accuracy 24.500
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [90][0/77]	Loss 0.4354 (0.4354)	Accuracy 86.719 (86.719)
# Epoch: [90][50/77]	Loss 0.4506 (0.4104)	Accuracy 85.156 (88.480)
# train_accuracy 88.898
# Test: [0/40]	Loss 3.8569 (3.8569)	Accuracy 0.000 (0.000)
# valid_accuracy 24.760
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [91][0/77]	Loss 0.5261 (0.5261)	Accuracy 83.594 (83.594)
# Epoch: [91][50/77]	Loss 0.5594 (0.4121)	Accuracy 85.156 (88.388)
# train_accuracy 88.490
# Test: [0/40]	Loss 4.0170 (4.0170)	Accuracy 0.000 (0.000)
# valid_accuracy 24.840
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [92][0/77]	Loss 0.2331 (0.2331)	Accuracy 94.531 (94.531)
# Epoch: [92][50/77]	Loss 0.6035 (0.4052)	Accuracy 85.938 (88.955)
# train_accuracy 88.929
# Test: [0/40]	Loss 3.8527 (3.8527)	Accuracy 0.000 (0.000)
# valid_accuracy 25.340
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [93][0/77]	Loss 0.5997 (0.5997)	Accuracy 85.938 (85.938)
# Epoch: [93][50/77]	Loss 0.3372 (0.4028)	Accuracy 92.188 (88.940)
# train_accuracy 88.765
# Test: [0/40]	Loss 3.8329 (3.8329)	Accuracy 0.000 (0.000)
# valid_accuracy 24.780
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [94][0/77]	Loss 0.4901 (0.4901)	Accuracy 87.500 (87.500)
# Epoch: [94][50/77]	Loss 0.4104 (0.4080)	Accuracy 88.281 (88.771)
# train_accuracy 88.837
# Test: [0/40]	Loss 3.8384 (3.8384)	Accuracy 0.000 (0.000)
# valid_accuracy 24.540
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [95][0/77]	Loss 0.3017 (0.3017)	Accuracy 92.969 (92.969)
# Epoch: [95][50/77]	Loss 0.3381 (0.3976)	Accuracy 89.844 (88.955)
# train_accuracy 88.959
# Test: [0/40]	Loss 3.9031 (3.9031)	Accuracy 0.000 (0.000)
# valid_accuracy 24.940
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [96][0/77]	Loss 0.5430 (0.5430)	Accuracy 82.031 (82.031)
# Epoch: [96][50/77]	Loss 0.3611 (0.4112)	Accuracy 91.406 (88.603)
# train_accuracy 88.643
# Test: [0/40]	Loss 3.9490 (3.9490)	Accuracy 0.000 (0.000)
# valid_accuracy 24.440
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [97][0/77]	Loss 0.4405 (0.4405)	Accuracy 86.719 (86.719)
# Epoch: [97][50/77]	Loss 0.5528 (0.4053)	Accuracy 85.938 (89.032)
# train_accuracy 88.929
# Test: [0/40]	Loss 3.9920 (3.9920)	Accuracy 0.000 (0.000)
# valid_accuracy 25.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [98][0/77]	Loss 0.4054 (0.4054)	Accuracy 85.156 (85.156)
# Epoch: [98][50/77]	Loss 0.2754 (0.4053)	Accuracy 92.969 (88.680)
# train_accuracy 88.653
# Test: [0/40]	Loss 3.9179 (3.9179)	Accuracy 0.000 (0.000)
# valid_accuracy 24.360
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [99][0/77]	Loss 0.2949 (0.2949)	Accuracy 91.406 (91.406)
# Epoch: [99][50/77]	Loss 0.3520 (0.3967)	Accuracy 90.625 (89.124)
# train_accuracy 89.031
# Test: [0/40]	Loss 3.9478 (3.9478)	Accuracy 0.000 (0.000)
# valid_accuracy 24.840
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [100][0/77]	Loss 0.3884 (0.3884)	Accuracy 88.281 (88.281)
# Epoch: [100][50/77]	Loss 0.3651 (0.3880)	Accuracy 90.625 (89.185)
# train_accuracy 88.867
# Test: [0/40]	Loss 4.0346 (4.0346)	Accuracy 0.000 (0.000)
# valid_accuracy 24.480
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [101][0/77]	Loss 0.4816 (0.4816)	Accuracy 85.938 (85.938)
# Epoch: [101][50/77]	Loss 0.4334 (0.4022)	Accuracy 88.281 (88.955)
# train_accuracy 89.255
# Test: [0/40]	Loss 3.8403 (3.8403)	Accuracy 0.000 (0.000)
# valid_accuracy 25.980
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [102][0/77]	Loss 0.2675 (0.2675)	Accuracy 95.312 (95.312)
# Epoch: [102][50/77]	Loss 0.2768 (0.3985)	Accuracy 92.969 (88.848)
# train_accuracy 88.908
# Test: [0/40]	Loss 3.9562 (3.9562)	Accuracy 0.000 (0.000)
# valid_accuracy 24.880
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [103][0/77]	Loss 0.2539 (0.2539)	Accuracy 92.969 (92.969)
# Epoch: [103][50/77]	Loss 0.4130 (0.3879)	Accuracy 88.281 (89.445)
# train_accuracy 89.235
# Test: [0/40]	Loss 3.9568 (3.9568)	Accuracy 0.000 (0.000)
# valid_accuracy 25.800
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [104][0/77]	Loss 0.3494 (0.3494)	Accuracy 92.969 (92.969)
# Epoch: [104][50/77]	Loss 0.5417 (0.3936)	Accuracy 85.156 (88.955)
# train_accuracy 89.041
# Test: [0/40]	Loss 3.9489 (3.9489)	Accuracy 0.000 (0.000)
# valid_accuracy 25.580
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [105][0/77]	Loss 0.3297 (0.3297)	Accuracy 92.188 (92.188)
# Epoch: [105][50/77]	Loss 0.4623 (0.3994)	Accuracy 87.500 (88.940)
# train_accuracy 89.020
# Test: [0/40]	Loss 4.0578 (4.0578)	Accuracy 0.000 (0.000)
# valid_accuracy 25.060
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [106][0/77]	Loss 0.4892 (0.4892)	Accuracy 85.156 (85.156)
# Epoch: [106][50/77]	Loss 0.3942 (0.3995)	Accuracy 88.281 (88.971)
# train_accuracy 89.214
# Test: [0/40]	Loss 3.6967 (3.6967)	Accuracy 0.000 (0.000)
# valid_accuracy 25.180
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [107][0/77]	Loss 0.2741 (0.2741)	Accuracy 92.188 (92.188)
# Epoch: [107][50/77]	Loss 0.5398 (0.3866)	Accuracy 84.375 (89.461)
# train_accuracy 89.143
# Test: [0/40]	Loss 3.8341 (3.8341)	Accuracy 0.000 (0.000)
# valid_accuracy 26.040
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [108][0/77]	Loss 0.3310 (0.3310)	Accuracy 89.844 (89.844)
# Epoch: [108][50/77]	Loss 0.4579 (0.4097)	Accuracy 85.938 (88.434)
# train_accuracy 88.918
# Test: [0/40]	Loss 3.8991 (3.8991)	Accuracy 0.000 (0.000)
# valid_accuracy 24.700
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [109][0/77]	Loss 0.4921 (0.4921)	Accuracy 85.156 (85.156)
# Epoch: [109][50/77]	Loss 0.4778 (0.3971)	Accuracy 88.281 (88.863)
# train_accuracy 88.908
# Test: [0/40]	Loss 3.8195 (3.8195)	Accuracy 0.000 (0.000)
# valid_accuracy 26.500
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [110][0/77]	Loss 0.3407 (0.3407)	Accuracy 91.406 (91.406)
# Epoch: [110][50/77]	Loss 0.4013 (0.4019)	Accuracy 88.281 (88.863)
# train_accuracy 89.051
# Test: [0/40]	Loss 4.0374 (4.0374)	Accuracy 0.000 (0.000)
# valid_accuracy 25.600
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [111][0/77]	Loss 0.3708 (0.3708)	Accuracy 88.281 (88.281)
# Epoch: [111][50/77]	Loss 0.3591 (0.3728)	Accuracy 92.188 (89.430)
# train_accuracy 89.082
# Test: [0/40]	Loss 3.8978 (3.8978)	Accuracy 0.000 (0.000)
# valid_accuracy 26.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [112][0/77]	Loss 0.4751 (0.4751)	Accuracy 85.156 (85.156)
# Epoch: [112][50/77]	Loss 0.3027 (0.3960)	Accuracy 92.188 (88.940)
# train_accuracy 89.184
# Test: [0/40]	Loss 3.9559 (3.9559)	Accuracy 0.000 (0.000)
# valid_accuracy 25.760
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [113][0/77]	Loss 0.4150 (0.4150)	Accuracy 89.062 (89.062)
# Epoch: [113][50/77]	Loss 0.4449 (0.4009)	Accuracy 89.062 (88.971)
# train_accuracy 89.112
# Test: [0/40]	Loss 3.9973 (3.9973)	Accuracy 0.000 (0.000)
# valid_accuracy 25.180
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [114][0/77]	Loss 0.3645 (0.3645)	Accuracy 89.062 (89.062)
# Epoch: [114][50/77]	Loss 0.4666 (0.3733)	Accuracy 89.062 (89.706)
# train_accuracy 89.316
# Test: [0/40]	Loss 3.9563 (3.9563)	Accuracy 0.000 (0.000)
# valid_accuracy 25.620
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [115][0/77]	Loss 0.4669 (0.4669)	Accuracy 87.500 (87.500)
# Epoch: [115][50/77]	Loss 0.4271 (0.3797)	Accuracy 88.281 (89.614)
# train_accuracy 89.327
# Test: [0/40]	Loss 4.0276 (4.0276)	Accuracy 0.000 (0.000)
# valid_accuracy 25.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [116][0/77]	Loss 0.4023 (0.4023)	Accuracy 86.719 (86.719)
# Epoch: [116][50/77]	Loss 0.3531 (0.3762)	Accuracy 91.406 (89.645)
# train_accuracy 89.163
# Test: [0/40]	Loss 3.8948 (3.8948)	Accuracy 0.000 (0.000)
# valid_accuracy 25.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [117][0/77]	Loss 0.4279 (0.4279)	Accuracy 85.938 (85.938)
# Epoch: [117][50/77]	Loss 0.4813 (0.3985)	Accuracy 84.375 (88.787)
# train_accuracy 89.153
# Test: [0/40]	Loss 3.9283 (3.9283)	Accuracy 0.000 (0.000)
# valid_accuracy 25.200
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [118][0/77]	Loss 0.3029 (0.3029)	Accuracy 91.406 (91.406)
# Epoch: [118][50/77]	Loss 0.4235 (0.3801)	Accuracy 87.500 (89.537)
# train_accuracy 89.296
# Test: [0/40]	Loss 4.0899 (4.0899)	Accuracy 0.000 (0.000)
# valid_accuracy 25.060
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [119][0/77]	Loss 0.4245 (0.4245)	Accuracy 89.844 (89.844)
# Epoch: [119][50/77]	Loss 0.3125 (0.3832)	Accuracy 89.844 (89.415)
# train_accuracy 89.327
# Test: [0/40]	Loss 3.7693 (3.7693)	Accuracy 0.000 (0.000)
# valid_accuracy 26.240
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [120][0/77]	Loss 0.2805 (0.2805)	Accuracy 91.406 (91.406)
# Epoch: [120][50/77]	Loss 0.3457 (0.3796)	Accuracy 90.625 (89.461)
# train_accuracy 89.367
# Test: [0/40]	Loss 4.2077 (4.2077)	Accuracy 0.000 (0.000)
# valid_accuracy 25.360
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [121][0/77]	Loss 0.3901 (0.3901)	Accuracy 87.500 (87.500)
# Epoch: [121][50/77]	Loss 0.4688 (0.3813)	Accuracy 87.500 (89.369)
# train_accuracy 89.459
# Test: [0/40]	Loss 4.0883 (4.0883)	Accuracy 0.000 (0.000)
# valid_accuracy 26.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [122][0/77]	Loss 0.4648 (0.4648)	Accuracy 88.281 (88.281)
# Epoch: [122][50/77]	Loss 0.4462 (0.3866)	Accuracy 85.938 (88.925)
# train_accuracy 89.153
# Test: [0/40]	Loss 3.9811 (3.9811)	Accuracy 0.000 (0.000)
# valid_accuracy 25.820
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [123][0/77]	Loss 0.2166 (0.2166)	Accuracy 94.531 (94.531)
# Epoch: [123][50/77]	Loss 0.4024 (0.3850)	Accuracy 87.500 (88.955)
# train_accuracy 89.112
# Test: [0/40]	Loss 3.8245 (3.8245)	Accuracy 0.000 (0.000)
# valid_accuracy 26.320
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [124][0/77]	Loss 0.3149 (0.3149)	Accuracy 92.188 (92.188)
# Epoch: [124][50/77]	Loss 0.4039 (0.3779)	Accuracy 86.719 (89.599)
# train_accuracy 89.439
# Test: [0/40]	Loss 3.9675 (3.9675)	Accuracy 0.000 (0.000)
# valid_accuracy 25.720
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [125][0/77]	Loss 0.5419 (0.5419)	Accuracy 83.594 (83.594)
# Epoch: [125][50/77]	Loss 0.2804 (0.3822)	Accuracy 90.625 (89.461)
# train_accuracy 89.459
# Test: [0/40]	Loss 3.9948 (3.9948)	Accuracy 0.000 (0.000)
# valid_accuracy 25.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [126][0/77]	Loss 0.3330 (0.3330)	Accuracy 91.406 (91.406)
# Epoch: [126][50/77]	Loss 0.3221 (0.3667)	Accuracy 91.406 (89.752)
# train_accuracy 89.510
# Test: [0/40]	Loss 3.7725 (3.7725)	Accuracy 0.000 (0.000)
# valid_accuracy 25.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [127][0/77]	Loss 0.3668 (0.3668)	Accuracy 89.844 (89.844)
# Epoch: [127][50/77]	Loss 0.3165 (0.3778)	Accuracy 92.188 (89.369)
# train_accuracy 89.449
# Test: [0/40]	Loss 3.8271 (3.8271)	Accuracy 0.000 (0.000)
# valid_accuracy 27.400
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [128][0/77]	Loss 0.1923 (0.1923)	Accuracy 94.531 (94.531)
# Epoch: [128][50/77]	Loss 0.3510 (0.3711)	Accuracy 90.625 (89.323)
# train_accuracy 89.378
# Test: [0/40]	Loss 4.0168 (4.0168)	Accuracy 0.000 (0.000)
# valid_accuracy 25.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [129][0/77]	Loss 0.3417 (0.3417)	Accuracy 92.188 (92.188)
# Epoch: [129][50/77]	Loss 0.2524 (0.3675)	Accuracy 93.750 (89.599)
# train_accuracy 89.561
# Test: [0/40]	Loss 3.9695 (3.9695)	Accuracy 0.000 (0.000)
# valid_accuracy 27.140
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [130][0/77]	Loss 0.3433 (0.3433)	Accuracy 89.844 (89.844)
# Epoch: [130][50/77]	Loss 0.4107 (0.3657)	Accuracy 90.625 (89.568)
# train_accuracy 89.531
# Test: [0/40]	Loss 3.7748 (3.7748)	Accuracy 0.000 (0.000)
# valid_accuracy 26.560
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [131][0/77]	Loss 0.3854 (0.3854)	Accuracy 89.844 (89.844)
# Epoch: [131][50/77]	Loss 0.3178 (0.3513)	Accuracy 91.406 (90.227)
# train_accuracy 89.724
# Test: [0/40]	Loss 4.0814 (4.0814)	Accuracy 0.000 (0.000)
# valid_accuracy 25.780
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [132][0/77]	Loss 0.2766 (0.2766)	Accuracy 93.750 (93.750)
# Epoch: [132][50/77]	Loss 0.3326 (0.3463)	Accuracy 92.188 (90.456)
# train_accuracy 89.888
# Test: [0/40]	Loss 3.7891 (3.7891)	Accuracy 0.000 (0.000)
# valid_accuracy 27.220
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [133][0/77]	Loss 0.5016 (0.5016)	Accuracy 85.156 (85.156)
# Epoch: [133][50/77]	Loss 0.4870 (0.3609)	Accuracy 82.031 (89.691)
# train_accuracy 89.520
# Test: [0/40]	Loss 3.9766 (3.9766)	Accuracy 0.000 (0.000)
# valid_accuracy 26.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [134][0/77]	Loss 0.3040 (0.3040)	Accuracy 90.625 (90.625)
# Epoch: [134][50/77]	Loss 0.3041 (0.3685)	Accuracy 92.188 (89.660)
# train_accuracy 89.684
# Test: [0/40]	Loss 3.9798 (3.9798)	Accuracy 0.000 (0.000)
# valid_accuracy 27.400
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [135][0/77]	Loss 0.3052 (0.3052)	Accuracy 91.406 (91.406)
# Epoch: [135][50/77]	Loss 0.4013 (0.3441)	Accuracy 89.844 (90.043)
# train_accuracy 89.724
# Test: [0/40]	Loss 3.8583 (3.8583)	Accuracy 0.000 (0.000)
# valid_accuracy 27.320
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [136][0/77]	Loss 0.3381 (0.3381)	Accuracy 90.625 (90.625)
# Epoch: [136][50/77]	Loss 0.2859 (0.3596)	Accuracy 91.406 (89.675)
# train_accuracy 89.643
# Test: [0/40]	Loss 3.8930 (3.8930)	Accuracy 0.000 (0.000)
# valid_accuracy 25.680
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [137][0/77]	Loss 0.2487 (0.2487)	Accuracy 92.188 (92.188)
# Epoch: [137][50/77]	Loss 0.2811 (0.3458)	Accuracy 93.750 (90.028)
# train_accuracy 89.724
# Test: [0/40]	Loss 3.8691 (3.8691)	Accuracy 0.000 (0.000)
# valid_accuracy 27.880
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [138][0/77]	Loss 0.1815 (0.1815)	Accuracy 96.094 (96.094)
# Epoch: [138][50/77]	Loss 0.3689 (0.3658)	Accuracy 88.281 (89.752)
# train_accuracy 89.806
# Test: [0/40]	Loss 4.3186 (4.3186)	Accuracy 0.000 (0.000)
# valid_accuracy 25.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [139][0/77]	Loss 0.2494 (0.2494)	Accuracy 88.281 (88.281)
# Epoch: [139][50/77]	Loss 0.3408 (0.3569)	Accuracy 90.625 (89.782)
# train_accuracy 89.786
# Test: [0/40]	Loss 4.0078 (4.0078)	Accuracy 0.000 (0.000)
# valid_accuracy 27.020
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [140][0/77]	Loss 0.3546 (0.3546)	Accuracy 89.844 (89.844)
# Epoch: [140][50/77]	Loss 0.2426 (0.3504)	Accuracy 94.531 (90.119)
# train_accuracy 89.796
# Test: [0/40]	Loss 3.8737 (3.8737)	Accuracy 0.000 (0.000)
# valid_accuracy 27.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [141][0/77]	Loss 0.3744 (0.3744)	Accuracy 87.500 (87.500)
# Epoch: [141][50/77]	Loss 0.3113 (0.3599)	Accuracy 90.625 (89.813)
# train_accuracy 89.929
# Test: [0/40]	Loss 3.6086 (3.6086)	Accuracy 0.000 (0.000)
# valid_accuracy 28.620
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [142][0/77]	Loss 0.2597 (0.2597)	Accuracy 92.188 (92.188)
# Epoch: [142][50/77]	Loss 0.3017 (0.3539)	Accuracy 92.188 (89.874)
# train_accuracy 90.051
# Test: [0/40]	Loss 4.1658 (4.1658)	Accuracy 0.000 (0.000)
# valid_accuracy 27.560
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [143][0/77]	Loss 0.5224 (0.5224)	Accuracy 85.156 (85.156)
# Epoch: [143][50/77]	Loss 0.2955 (0.3522)	Accuracy 92.969 (89.675)
# train_accuracy 89.755
# Test: [0/40]	Loss 3.7270 (3.7270)	Accuracy 0.000 (0.000)
# valid_accuracy 26.180
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [144][0/77]	Loss 0.3607 (0.3607)	Accuracy 89.062 (89.062)
# Epoch: [144][50/77]	Loss 0.4458 (0.3575)	Accuracy 86.719 (89.890)
# train_accuracy 90.051
# Test: [0/40]	Loss 3.8288 (3.8288)	Accuracy 0.000 (0.000)
# valid_accuracy 28.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [145][0/77]	Loss 0.3431 (0.3431)	Accuracy 91.406 (91.406)
# Epoch: [145][50/77]	Loss 0.3810 (0.3555)	Accuracy 89.844 (89.920)
# train_accuracy 90.163
# Test: [0/40]	Loss 3.9555 (3.9555)	Accuracy 0.000 (0.000)
# valid_accuracy 28.800
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [146][0/77]	Loss 0.4008 (0.4008)	Accuracy 87.500 (87.500)
# Epoch: [146][50/77]	Loss 0.4042 (0.3475)	Accuracy 87.500 (90.104)
# train_accuracy 89.959
# Test: [0/40]	Loss 3.9934 (3.9934)	Accuracy 0.000 (0.000)
# valid_accuracy 27.180
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [147][0/77]	Loss 0.2605 (0.2605)	Accuracy 92.188 (92.188)
# Epoch: [147][50/77]	Loss 0.3480 (0.3418)	Accuracy 89.844 (90.349)
# train_accuracy 90.480
# Test: [0/40]	Loss 3.8967 (3.8967)	Accuracy 0.000 (0.000)
# valid_accuracy 26.300
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [148][0/77]	Loss 0.2225 (0.2225)	Accuracy 92.969 (92.969)
# Epoch: [148][50/77]	Loss 0.4087 (0.3506)	Accuracy 86.719 (89.782)
# train_accuracy 89.980
# Test: [0/40]	Loss 3.7100 (3.7100)	Accuracy 0.000 (0.000)
# valid_accuracy 26.620
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [149][0/77]	Loss 0.3269 (0.3269)	Accuracy 89.062 (89.062)
# Epoch: [149][50/77]	Loss 0.2315 (0.3480)	Accuracy 93.750 (90.058)
# train_accuracy 90.133
# Test: [0/40]	Loss 4.1819 (4.1819)	Accuracy 0.000 (0.000)
# valid_accuracy 28.120
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [150][0/77]	Loss 0.2451 (0.2451)	Accuracy 92.188 (92.188)
# Epoch: [150][50/77]	Loss 0.3753 (0.3350)	Accuracy 87.500 (90.380)
# train_accuracy 90.112
# Test: [0/40]	Loss 4.2562 (4.2562)	Accuracy 0.000 (0.000)
# valid_accuracy 27.960
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [151][0/77]	Loss 0.2972 (0.2972)	Accuracy 92.969 (92.969)
# Epoch: [151][50/77]	Loss 0.3301 (0.3337)	Accuracy 92.188 (90.441)
# train_accuracy 90.551
# Test: [0/40]	Loss 4.1906 (4.1906)	Accuracy 0.000 (0.000)
# valid_accuracy 28.760
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [152][0/77]	Loss 0.2704 (0.2704)	Accuracy 94.531 (94.531)
# Epoch: [152][50/77]	Loss 0.4349 (0.3225)	Accuracy 88.281 (90.763)
# train_accuracy 90.541
# Test: [0/40]	Loss 4.4421 (4.4421)	Accuracy 0.000 (0.000)
# valid_accuracy 25.460
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [153][0/77]	Loss 0.2317 (0.2317)	Accuracy 93.750 (93.750)
# Epoch: [153][50/77]	Loss 0.2719 (0.3324)	Accuracy 92.188 (90.441)
# train_accuracy 90.316
# Test: [0/40]	Loss 4.2778 (4.2778)	Accuracy 0.000 (0.000)
# valid_accuracy 27.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [154][0/77]	Loss 0.2394 (0.2394)	Accuracy 94.531 (94.531)
# Epoch: [154][50/77]	Loss 0.2920 (0.3406)	Accuracy 90.625 (89.982)
# train_accuracy 90.327
# Test: [0/40]	Loss 4.0349 (4.0349)	Accuracy 0.000 (0.000)
# valid_accuracy 29.720
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [155][0/77]	Loss 0.3280 (0.3280)	Accuracy 90.625 (90.625)
# Epoch: [155][50/77]	Loss 0.4548 (0.3394)	Accuracy 85.938 (90.165)
# train_accuracy 90.255
# Test: [0/40]	Loss 4.0312 (4.0312)	Accuracy 0.000 (0.000)
# valid_accuracy 28.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [156][0/77]	Loss 0.3901 (0.3901)	Accuracy 91.406 (91.406)
# Epoch: [156][50/77]	Loss 0.4293 (0.3281)	Accuracy 89.844 (90.487)
# train_accuracy 90.469
# Test: [0/40]	Loss 3.9968 (3.9968)	Accuracy 0.000 (0.000)
# valid_accuracy 25.640
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [157][0/77]	Loss 0.2194 (0.2194)	Accuracy 94.531 (94.531)
# Epoch: [157][50/77]	Loss 0.3622 (0.3310)	Accuracy 90.625 (90.349)
# train_accuracy 90.490
# Test: [0/40]	Loss 4.0859 (4.0859)	Accuracy 0.000 (0.000)
# valid_accuracy 27.300
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [158][0/77]	Loss 0.3414 (0.3414)	Accuracy 90.625 (90.625)
# Epoch: [158][50/77]	Loss 0.2400 (0.3202)	Accuracy 92.969 (90.763)
# train_accuracy 90.480
# Test: [0/40]	Loss 4.1751 (4.1751)	Accuracy 0.000 (0.000)
# valid_accuracy 28.160
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [159][0/77]	Loss 0.3250 (0.3250)	Accuracy 87.500 (87.500)
# Epoch: [159][50/77]	Loss 0.3629 (0.3319)	Accuracy 89.062 (90.135)
# train_accuracy 90.337
# Test: [0/40]	Loss 3.7934 (3.7934)	Accuracy 0.000 (0.000)
# valid_accuracy 29.100
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [160][0/77]	Loss 0.3164 (0.3164)	Accuracy 90.625 (90.625)
# Epoch: [160][50/77]	Loss 0.3513 (0.3181)	Accuracy 90.625 (90.533)
# train_accuracy 90.306
# Test: [0/40]	Loss 4.0276 (4.0276)	Accuracy 0.000 (0.000)
# valid_accuracy 31.060
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [161][0/77]	Loss 0.4002 (0.4002)	Accuracy 91.406 (91.406)
# Epoch: [161][50/77]	Loss 0.2096 (0.3190)	Accuracy 96.094 (90.916)
# train_accuracy 90.612
# Test: [0/40]	Loss 4.3225 (4.3225)	Accuracy 0.000 (0.000)
# valid_accuracy 26.820
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [162][0/77]	Loss 0.2006 (0.2006)	Accuracy 95.312 (95.312)
# Epoch: [162][50/77]	Loss 0.2839 (0.3151)	Accuracy 90.625 (90.640)
# train_accuracy 90.500
# Test: [0/40]	Loss 3.8131 (3.8131)	Accuracy 0.000 (0.000)
# valid_accuracy 31.180
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [163][0/77]	Loss 0.4853 (0.4853)	Accuracy 85.938 (85.938)
# Epoch: [163][50/77]	Loss 0.3083 (0.3252)	Accuracy 90.625 (90.441)
# train_accuracy 90.653
# Test: [0/40]	Loss 4.1509 (4.1509)	Accuracy 0.000 (0.000)
# valid_accuracy 27.460
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [164][0/77]	Loss 0.5141 (0.5141)	Accuracy 87.500 (87.500)
# Epoch: [164][50/77]	Loss 0.2058 (0.3147)	Accuracy 92.969 (90.855)
# train_accuracy 90.888
# Test: [0/40]	Loss 4.1991 (4.1991)	Accuracy 0.000 (0.000)
# valid_accuracy 30.560
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [165][0/77]	Loss 0.4027 (0.4027)	Accuracy 85.938 (85.938)
# Epoch: [165][50/77]	Loss 0.2384 (0.3139)	Accuracy 92.969 (90.686)
# train_accuracy 90.724
# Test: [0/40]	Loss 4.3604 (4.3604)	Accuracy 0.000 (0.000)
# valid_accuracy 28.840
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [166][0/77]	Loss 0.3328 (0.3328)	Accuracy 89.844 (89.844)
# Epoch: [166][50/77]	Loss 0.4951 (0.3230)	Accuracy 87.500 (90.594)
# train_accuracy 90.898
# Test: [0/40]	Loss 3.8470 (3.8470)	Accuracy 0.000 (0.000)
# valid_accuracy 31.080
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [167][0/77]	Loss 0.2598 (0.2598)	Accuracy 92.969 (92.969)
# Epoch: [167][50/77]	Loss 0.3578 (0.3138)	Accuracy 91.406 (90.564)
# train_accuracy 90.469
# Test: [0/40]	Loss 4.5058 (4.5058)	Accuracy 0.000 (0.000)
# valid_accuracy 29.760
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [168][0/77]	Loss 0.4267 (0.4267)	Accuracy 88.281 (88.281)
# Epoch: [168][50/77]	Loss 0.3588 (0.3136)	Accuracy 85.938 (90.564)
# train_accuracy 90.571
# Test: [0/40]	Loss 4.0993 (4.0993)	Accuracy 0.000 (0.000)
# valid_accuracy 27.820
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [169][0/77]	Loss 0.2732 (0.2732)	Accuracy 90.625 (90.625)
# Epoch: [169][50/77]	Loss 0.2394 (0.3054)	Accuracy 95.312 (91.023)
# train_accuracy 90.990
# Test: [0/40]	Loss 4.6142 (4.6142)	Accuracy 0.000 (0.000)
# valid_accuracy 28.880
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [170][0/77]	Loss 0.3283 (0.3283)	Accuracy 85.938 (85.938)
# Epoch: [170][50/77]	Loss 0.2634 (0.3090)	Accuracy 91.406 (90.855)
# train_accuracy 90.694
# Test: [0/40]	Loss 4.0188 (4.0188)	Accuracy 0.000 (0.000)
# valid_accuracy 29.300
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [171][0/77]	Loss 0.3643 (0.3643)	Accuracy 89.062 (89.062)
# Epoch: [171][50/77]	Loss 0.2261 (0.3083)	Accuracy 95.312 (90.901)
# train_accuracy 91.051
# Test: [0/40]	Loss 3.7987 (3.7987)	Accuracy 0.000 (0.000)
# valid_accuracy 30.140
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [172][0/77]	Loss 0.3972 (0.3972)	Accuracy 88.281 (88.281)
# Epoch: [172][50/77]	Loss 0.2920 (0.3138)	Accuracy 91.406 (90.931)
# train_accuracy 91.194
# Test: [0/40]	Loss 4.3769 (4.3769)	Accuracy 0.000 (0.000)
# valid_accuracy 29.300
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [173][0/77]	Loss 0.3989 (0.3989)	Accuracy 89.062 (89.062)
# Epoch: [173][50/77]	Loss 0.2462 (0.2972)	Accuracy 92.969 (91.422)
# train_accuracy 91.163
# Test: [0/40]	Loss 3.9166 (3.9166)	Accuracy 0.000 (0.000)
# valid_accuracy 28.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [174][0/77]	Loss 0.2743 (0.2743)	Accuracy 89.844 (89.844)
# Epoch: [174][50/77]	Loss 0.2454 (0.3047)	Accuracy 92.969 (91.085)
# train_accuracy 91.051
# Test: [0/40]	Loss 4.2375 (4.2375)	Accuracy 0.000 (0.000)
# valid_accuracy 28.140
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [175][0/77]	Loss 0.2256 (0.2256)	Accuracy 92.969 (92.969)
# Epoch: [175][50/77]	Loss 0.2725 (0.2843)	Accuracy 92.969 (91.529)
# train_accuracy 91.153
# Test: [0/40]	Loss 4.1926 (4.1926)	Accuracy 0.000 (0.000)
# valid_accuracy 30.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [176][0/77]	Loss 0.2885 (0.2885)	Accuracy 92.188 (92.188)
# Epoch: [176][50/77]	Loss 0.3527 (0.2964)	Accuracy 89.062 (90.885)
# train_accuracy 90.929
# Test: [0/40]	Loss 3.8165 (3.8165)	Accuracy 0.000 (0.000)
# valid_accuracy 26.900
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [177][0/77]	Loss 0.3351 (0.3351)	Accuracy 89.062 (89.062)
# Epoch: [177][50/77]	Loss 0.2320 (0.2956)	Accuracy 94.531 (91.023)
# train_accuracy 90.867
# Test: [0/40]	Loss 4.2664 (4.2664)	Accuracy 0.000 (0.000)
# valid_accuracy 29.060
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [178][0/77]	Loss 0.2855 (0.2855)	Accuracy 91.406 (91.406)
# Epoch: [178][50/77]	Loss 0.2762 (0.2999)	Accuracy 92.188 (91.299)
# train_accuracy 91.316
# Test: [0/40]	Loss 4.7582 (4.7582)	Accuracy 0.000 (0.000)
# valid_accuracy 28.660
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [179][0/77]	Loss 0.3219 (0.3219)	Accuracy 89.844 (89.844)
# Epoch: [179][50/77]	Loss 0.2946 (0.3000)	Accuracy 92.188 (91.054)
# train_accuracy 91.184
# Test: [0/40]	Loss 4.1538 (4.1538)	Accuracy 0.000 (0.000)
# valid_accuracy 30.680
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [180][0/77]	Loss 0.2857 (0.2857)	Accuracy 91.406 (91.406)
# Epoch: [180][50/77]	Loss 0.2171 (0.3010)	Accuracy 95.312 (91.192)
# train_accuracy 91.184
# Test: [0/40]	Loss 4.3444 (4.3444)	Accuracy 0.000 (0.000)
# valid_accuracy 28.420
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [181][0/77]	Loss 0.3777 (0.3777)	Accuracy 88.281 (88.281)
# Epoch: [181][50/77]	Loss 0.3025 (0.2992)	Accuracy 92.188 (90.947)
# train_accuracy 91.163
# Test: [0/40]	Loss 3.7140 (3.7140)	Accuracy 0.000 (0.000)
# valid_accuracy 31.540
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [182][0/77]	Loss 0.2450 (0.2450)	Accuracy 92.188 (92.188)
# Epoch: [182][50/77]	Loss 0.2966 (0.2721)	Accuracy 92.969 (91.590)
# train_accuracy 91.224
# Test: [0/40]	Loss 3.9478 (3.9478)	Accuracy 0.000 (0.000)
# valid_accuracy 27.740
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [183][0/77]	Loss 0.2292 (0.2292)	Accuracy 92.969 (92.969)
# Epoch: [183][50/77]	Loss 0.3936 (0.2819)	Accuracy 89.062 (91.667)
# train_accuracy 91.296
# Test: [0/40]	Loss 4.4658 (4.4658)	Accuracy 0.000 (0.000)
# valid_accuracy 28.840
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [184][0/77]	Loss 0.1655 (0.1655)	Accuracy 94.531 (94.531)
# Epoch: [184][50/77]	Loss 0.1467 (0.2754)	Accuracy 95.312 (91.452)
# train_accuracy 91.429
# Test: [0/40]	Loss 3.7876 (3.7876)	Accuracy 0.000 (0.000)
# valid_accuracy 31.620
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [185][0/77]	Loss 0.2897 (0.2897)	Accuracy 92.188 (92.188)
# Epoch: [185][50/77]	Loss 0.2600 (0.2950)	Accuracy 93.750 (91.268)
# train_accuracy 91.510
# Test: [0/40]	Loss 4.7564 (4.7564)	Accuracy 0.000 (0.000)
# valid_accuracy 30.100
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [186][0/77]	Loss 0.2854 (0.2854)	Accuracy 91.406 (91.406)
# Epoch: [186][50/77]	Loss 0.3178 (0.2784)	Accuracy 90.625 (91.636)
# train_accuracy 91.469
# Test: [0/40]	Loss 3.7735 (3.7735)	Accuracy 0.000 (0.000)
# valid_accuracy 31.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [187][0/77]	Loss 0.1607 (0.1607)	Accuracy 97.656 (97.656)
# Epoch: [187][50/77]	Loss 0.2563 (0.2760)	Accuracy 92.188 (91.697)
# train_accuracy 91.673
# Test: [0/40]	Loss 4.2809 (4.2809)	Accuracy 0.000 (0.000)
# valid_accuracy 28.040
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [188][0/77]	Loss 0.2211 (0.2211)	Accuracy 92.969 (92.969)
# Epoch: [188][50/77]	Loss 0.2858 (0.2778)	Accuracy 93.750 (91.759)
# train_accuracy 91.622
# Test: [0/40]	Loss 4.8603 (4.8603)	Accuracy 0.000 (0.000)
# valid_accuracy 29.740
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [189][0/77]	Loss 0.3110 (0.3110)	Accuracy 89.062 (89.062)
# Epoch: [189][50/77]	Loss 0.2883 (0.2809)	Accuracy 88.281 (91.575)
# train_accuracy 91.510
# Test: [0/40]	Loss 4.0823 (4.0823)	Accuracy 0.000 (0.000)
# valid_accuracy 30.040
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [190][0/77]	Loss 0.3018 (0.3018)	Accuracy 88.281 (88.281)
# Epoch: [190][50/77]	Loss 0.2801 (0.2678)	Accuracy 90.625 (91.866)
# train_accuracy 91.939
# Test: [0/40]	Loss 3.5742 (3.5742)	Accuracy 0.000 (0.000)
# valid_accuracy 30.300
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [191][0/77]	Loss 0.1916 (0.1916)	Accuracy 92.969 (92.969)
# Epoch: [191][50/77]	Loss 0.2151 (0.2721)	Accuracy 94.531 (91.759)
# train_accuracy 91.633
# Test: [0/40]	Loss 3.9987 (3.9987)	Accuracy 0.000 (0.000)
# valid_accuracy 28.300
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [192][0/77]	Loss 0.1854 (0.1854)	Accuracy 94.531 (94.531)
# Epoch: [192][50/77]	Loss 0.2270 (0.2718)	Accuracy 93.750 (91.621)
# train_accuracy 91.755
# Test: [0/40]	Loss 5.0448 (5.0448)	Accuracy 0.000 (0.000)
# valid_accuracy 27.380
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [193][0/77]	Loss 0.2241 (0.2241)	Accuracy 91.406 (91.406)
# Epoch: [193][50/77]	Loss 0.2135 (0.2568)	Accuracy 93.750 (92.157)
# train_accuracy 91.888
# Test: [0/40]	Loss 4.7818 (4.7818)	Accuracy 0.000 (0.000)
# valid_accuracy 30.080
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [194][0/77]	Loss 0.2686 (0.2686)	Accuracy 92.188 (92.188)
# Epoch: [194][50/77]	Loss 0.2755 (0.2467)	Accuracy 89.844 (92.601)
# train_accuracy 92.122
# Test: [0/40]	Loss 4.4828 (4.4828)	Accuracy 0.000 (0.000)
# valid_accuracy 30.940
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [195][0/77]	Loss 0.2259 (0.2259)	Accuracy 94.531 (94.531)
# Epoch: [195][50/77]	Loss 0.3111 (0.2657)	Accuracy 87.500 (91.636)
# train_accuracy 91.755
# Test: [0/40]	Loss 3.9625 (3.9625)	Accuracy 0.000 (0.000)
# valid_accuracy 30.220
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [196][0/77]	Loss 0.2195 (0.2195)	Accuracy 93.750 (93.750)
# Epoch: [196][50/77]	Loss 0.4144 (0.2693)	Accuracy 87.500 (91.713)
# train_accuracy 91.857
# Test: [0/40]	Loss 4.9117 (4.9117)	Accuracy 0.000 (0.000)
# valid_accuracy 26.520
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [197][0/77]	Loss 0.2695 (0.2695)	Accuracy 92.188 (92.188)
# Epoch: [197][50/77]	Loss 0.3407 (0.2531)	Accuracy 89.062 (92.203)
# train_accuracy 92.000
# Test: [0/40]	Loss 4.6405 (4.6405)	Accuracy 0.000 (0.000)
# valid_accuracy 28.000
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [198][0/77]	Loss 0.1668 (0.1668)	Accuracy 92.969 (92.969)
# Epoch: [198][50/77]	Loss 0.2268 (0.2501)	Accuracy 91.406 (92.387)
# train_accuracy 92.133
# Test: [0/40]	Loss 3.6586 (3.6586)	Accuracy 0.781 (0.781)
# valid_accuracy 32.260
# ==================================================
# The learning rate is 0.0010000000000000002
# Epoch: [199][0/77]	Loss 0.2461 (0.2461)	Accuracy 92.188 (92.188)
# Epoch: [199][50/77]	Loss 0.2294 (0.2626)	Accuracy 94.531 (91.881)
# train_accuracy 92.245
# Test: [0/40]	Loss 4.0434 (4.0434)	Accuracy 0.000 (0.000)
# valid_accuracy 31.440
