# %%
import pandas as pd
import numpy as np

# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline

# %%
excluded = pd.read_csv('/data/Projects/ACC_NCDR/NCDR/BJMDATA/ACTION/NCHData/temp/exclude_pt.csv',
                       encoding='ISO-8859-1',
                       low_memory=False)

# %%
included = pd.read_csv('/data/Projects/ACC_NCDR/NCDR/BJMDATA/ACTION/NCHData/temp/include_pt.csv',
                       encoding='ISO-8859-1',
                       low_memory=False)

# %%
excluded.ZipCode.hist()

# %%
included.ZipCode.hist()

# %%
included.Timeframe.hist()

# %%
included.Timeframe.hist()

# %%
excluded.AdmitDate.hist(range=(18500, 21000))

# %%
included.AdmitDate.hist(range=(18500, 21000))

# %%
included.AdmitDate.min(), included.AdmitDate.max(), excluded.AdmitDate.min(), excluded.AdmitDate.max()
# Out:
# (15389.0, 20819.0, 18598.0, 20819.0)

# %%
excluded.Timeframe.hist()

# %%
[foo for foo in excluded.columns if 'time' in foo.lower()]
# Out:
# ['Timeframe',
#  'ArrivalTime',
#  'ArrOutHospTime',
#  'ArrOutHospTimeEst',
#  'CABGTime',
#  'CathArrivalTime',
#  'DeathTime',
#  'DiagCorAngioTime',
#  'FirstDevActiTime',
#  'FirstECGTime',
#  'FirstMedConTime',
#  'FirstMedConTimeEst',
#  'InitCKMBTime',
#  'InitCreatTime',
#  'InitHemoTime',
#  'InitHGBTime',
#  'InitINRTime',
#  'InitTropTime',
#  'LipidsTime',
#  'LowHGBTime',
#  'OnsetTime',
#  'OnsetTimeEst',
#  'OnsetTimeNA',
#  'PeakCKMBTime',
#  'PeakCreatTime',
#  'PeakTropTime',
#  'SubECGTime',
#  'ThromTime',
#  'TranOutEDTime',
#  'TranOutFacTime',
#  'TranOutFacTimeEst',
#  'TransTime',
#  'NonEMSFirstMedConTime',
#  'NonEMSFirstMedConTimeEst',
#  'EMSDispatchTime',
#  'EMSLeavingSceneTime',
#  'CathLabActivationTime',
#  'ASA_First24StartTime',
#  'CLPD_First24StartTime',
#  'Ticlid_First24StartTime',
#  'BB_First24StartTime',
#  'Prasu_First24StartTime',
#  'Tic_First24StartTime',
#  'Fonda_StartTime',
#  'UFH_StartTime',
#  'BivalTime',
#  'Eptif_StartTime',
# ...

# %%
bar = excluded.columns.to_list()

# %%
bar.sort()

# %%
bar
# Out:
# ['ABA_DC',
#  'ABA_First24',
#  'ABA_Home',
#  'ACE_DC',
#  'ACE_First24',
#  'ACE_Home',
#  'ACTOperatorKey',
#  'ADFMSD21',
#  'ARB_DC',
#  'ARB_First24',
#  'ARB_Home',
#  'ASA_DC',
#  'ASA_DCDose',
#  'ASA_DoseAtDC',
#  'ASA_First24',
#  'ASA_First24StartDate',
#  'ASA_First24StartTime',
#  'ASA_Home',
#  'Abcix',
#  'AbcixDose',
#  'Abcix_StartDate',
#  'Abcix_StartTime',
#  'AccessSite',
#  'AdmitDate',
#  'Age',
#  'AgeDaysArrival',
#  'AgeDaysDeath',
#  'Apixaban_DC',
#  'Apixaban_Home',
#  'Arga',
#  'ArgaDate',
#  'ArgaTime',
#  'ArrOutHospDate',
#  'ArrOutHospTime',
#  'ArrOutHospTimeEst',
#  'ArrivalDate',
#  'ArrivalTime',
#  'BB_DC',
#  'BB_First24',
#  'BB_First24StartDate',
#  'BB_First24StartTime',
#  'BB_Home',
#  'BNP',
#  'BNPValue',
#  'BareMetalStent',
#  'BasicADLs',
#  'Bival',
#  'BivalDate',
#  'BivalTime',
#  'BodyMassIndex',
#  'CABG',
#  'CABGDate',
#  'CABGTime',
#  'CAFirstMedCon',
#  'CAOutHosp',
#  'CAPreHosp',
#  'CEAtrialFib',
#  'CEAtrialFibDate',
# ...
